# %%
# !pip install finance-datareader

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import os

# %matplotlib inline
warnings.filterwarnings('ignore')

plt.rcParams['font.family'] = 'NanumGothic'

# %%
import FinanceDataReader as fdr

# %%
df = fdr.StockListing('KRX')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6834 entries, 0 to 6833
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Symbol          6834 non-null   object
#  1   Market          6834 non-null   object
#  2   Name            6834 non-null   object
#  3   Sector          2466 non-null   object
#  4   Industry        2447 non-null   object
#  5   ListingDate     2466 non-null   datetime64[ns]
#  6   SettleMonth     2466 non-null   object
#  7   Representative  2466 non-null   object
#  8   HomePage        2318 non-null   object
#  9   Region          2466 non-null   object
# dtypes: datetime64[ns](1), object(9)
# memory usage: 587.3+ KB

# %%
df
# Out:
#       Symbol  Market     Name                    Sector  \
# 0     060310  KOSDAQ       3S                  전자부품 제조업
# 1     095570   KOSPI   AJ네트웍스           산업용 기계 및 장비 임대업
# 2     006840   KOSPI    AK홀딩스                    기타 금융업
# 3     054620  KOSDAQ   APS홀딩스                    기타 금융업
# 4     265520  KOSDAQ    AP시스템             특수 목적용 기계 제조업
# ...      ...     ...      ...                       ...
# 6829  000547   KOSPI  흥국화재2우B                       NaN
# 6830  000545   KOSPI    흥국화재우                       NaN
# 6831  003280   KOSPI     흥아해운                    해상 운송업
# 6832  037440  KOSDAQ       희림  건축기술, 엔지니어링 및 관련 기술 서비스업
# 6833  238490  KOSDAQ       힘스             특수 목적용 기계 제조업
#
#                             Industry ListingDate SettleMonth  \
# 0                        반도체 웨이퍼 캐리어  2002-04-23         03월
# 1                렌탈(파렛트, OA장비, 건설장비)  2015-08-21         12월
# 2                               지주사업  1999-08-11         12월
# 3                        인터넷 트래픽 솔루션  2001-12-04         12월
# 4                        디스플레이 제조 장비  2017-04-07         12월
# ...                              ...         ...         ...
# 6829                             NaN         NaT         NaN
# 6830                             NaN         NaT         NaN
# 6831                  외항화물운송업(케미컬탱커)  1976-06-29         12월
# 6832                       설계 및 감리용역  2000-02-03         12월
# 6833  OLED Mask 인장기, OLED Mask 검사기 등  2017-07-20         12월
#
#             Representative                       HomePage Region
# 0       박종익, 김세완 (각자 대표이사)           http://www.3sref.com  서울특별시
# 1                      박대현         http://www.ajnet.co.kr  서울특별시
# 2        채형석, 이석주(각자 대표이사)  http://www.aekyunggroup.co.kr  서울특별시
# 3                      정기로   http://www.apsholdings.co.kr    경기도
# 4                      김영주     http://www.apsystems.co.kr    경기도
# ...                    ...                            ...    ...
# 6829                   NaN                            NaN    NaN
# 6830                   NaN                            NaN    NaN
# 6831                   이환구         http://www.heung-a.com  서울특별시
# 6832  정영균, 이목운, 허철호 (각자대표)          http://www.heerim.com  서울특별시
# 6833                   김주환          http://www.hims.co.kr  인천광역시
#
# [6834 rows x 10 columns]

# %%
df[df['Name'] == '카카오']
# Out:
#       Symbol Market Name                            Sector         Industry  \
# 4947  035720  KOSPI  카카오  자료처리, 호스팅, 포털 및 기타 인터넷 정보매개 서비스업  인터넷 서비스(인터넷 광고)
#
#      ListingDate SettleMonth Representative                  HomePage   Region
# 4947  2017-07-10         12월       여민수, 조수용  http://www.kakaocorp.com  제주특별자치도

# %%
serach = '삼성전자'
df[df['Name'] == serach]
# Out:
#       Symbol Market  Name          Sector  \
# 3735  005930  KOSPI  삼성전자  통신 및 방송 장비 제조업
#
#                                                Industry ListingDate  \
# 3735  IMT2000 서비스용 동기식 기지국,교환국장비,데이터단말기,동영상휴대폰,핵심칩,반...  1975-06-11
#
#      SettleMonth Representative              HomePage Region
# 3735         12월  김기남, 김현석, 고동진  http://www.sec.co.kr    경기도

# %%
stock = fdr.DataReader('005930')
stock.tail(20)
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2021-09-15  77400  77400  76400  77000  12829128  0.005222
# 2021-09-16  77300  77400  76100  76100  13067622 -0.011688
# 2021-09-17  76300  77200  75900  77200  16289502  0.014455
# 2021-09-23  77500  77600  76800  77400  17055590  0.002591
# 2021-09-24  77600  77700  77100  77300  12247274 -0.001292
# 2021-09-27  77300  77700  77000  77700  11699798  0.005175
# 2021-09-28  77700  77800  76200  76300  15406382 -0.018018
# 2021-09-29  74800  75300  73800  74100  23992458 -0.028834
# 2021-09-30  74300  74800  73700  74100  19919361  0.000000
# 2021-10-01  73900  74000  72900  73200  15803395 -0.012146
# 2021-10-05  73000  73000  71400  72200  24013921 -0.013661
# 2021-10-06  72600  72800  71200  71300  18956962 -0.012465
# 2021-10-07  71600  72100  71300  71600  13683532  0.004208
# 2021-10-08  72300  72400  71500  71500  14043287 -0.001397
# 2021-10-12  70700  70900  68700  69000  31001484 -0.034965
# 2021-10-13  68700  69600  68300  68800  24172015 -0.002899
# 2021-10-14  69000  69800  68800  69400  19520641  0.008721
# 2021-10-15  70200  71000  70000  70100  18051612  0.010086
# 2021-10-18  70200  70300  69200  70200  13486391  0.001427
# 2021-10-19  70800  71000  70400  70600   9472565  0.005698

# %%
stock = fdr.DataReader('005930', '2021') # 21년도 자료만 보기
stock
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2021-01-04  81000  84400  80200  83000  38655276  0.024691
# 2021-01-05  81600  83900  81600  83900  35335669  0.010843
# 2021-01-06  83300  84500  82100  82200  42089013 -0.020262
# 2021-01-07  82800  84200  82700  82900  32644642  0.008516
# 2021-01-08  83300  90000  83000  88800  59013307  0.071170
# ...           ...    ...    ...    ...       ...       ...
# 2021-10-13  68700  69600  68300  68800  24172015 -0.002899
# 2021-10-14  69000  69800  68800  69400  19520641  0.008721
# 2021-10-15  70200  71000  70000  70100  18051612  0.010086
# 2021-10-18  70200  70300  69200  70200  13486391  0.001427
# 2021-10-19  70800  71000  70400  70600   9472565  0.005698
#
# [196 rows x 6 columns]

# %%
# 이름 검색시 심볼번호 자동으로 검색되도록 짜보기

search = '삼성전자'
search=df[df['Name'] == search]
display(search)
search_num=search['Symbol']
print(type(search_num))
# Out:
#       Symbol Market  Name          Sector  \
# 3735  005930  KOSPI  삼성전자  통신 및 방송 장비 제조업
#
#                                                Industry ListingDate  \
# 3735  IMT2000 서비스용 동기식 기지국,교환국장비,데이터단말기,동영상휴대폰,핵심칩,반...  1975-06-11
#
#      SettleMonth Representative              HomePage Region
# 3735         12월  김기남, 김현석, 고동진  http://www.sec.co.kr    경기도
# <class 'pandas.core.series.Series'>

# %%
# 방법1 리스트화 시켜 0번째 자료 넣기
search_num = list(search_num.values)
search_num = search_num[0]
search_num
# Out:
# '005930'

# %%
stock = fdr.DataReader(search_num)
stock
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 1997-09-24   1186   1213   1165   1194     93880       NaN
# 1997-09-25   1193   1193   1170   1179     70400 -0.012563
# 1997-09-26   1170   1179   1161   1174     70500 -0.004241
# 1997-09-27   1170   1170   1152   1158     84610 -0.013629
# 1997-09-29   1143   1172   1143   1162     48510  0.003454
# ...           ...    ...    ...    ...       ...       ...
# 2021-10-13  68700  69600  68300  68800  24172015 -0.002899
# 2021-10-14  69000  69800  68800  69400  19520641  0.008721
# 2021-10-15  70200  71000  70000  70100  18051612  0.010086
# 2021-10-18  70200  70300  69200  70200  13486391  0.001427
# 2021-10-19  70800  71000  70400  70600   9472565  0.005698
#
# [6000 rows x 6 columns]

# %%
# 방법2 in로 바꾸고 숫자를 맞추고 0을 채워야 함
search_num = int(search['Symbol'])
search_num = str(search_num).zfill(6)
search_num
# Out:
# '005930'

# %%
stock = fdr.DataReader(search_num)
stock # 시가, 고가, 저가, 종가, 거래량, 대비
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 1997-09-24   1186   1213   1165   1194     93880       NaN
# 1997-09-25   1193   1193   1170   1179     70400 -0.012563
# 1997-09-26   1170   1179   1161   1174     70500 -0.004241
# 1997-09-27   1170   1170   1152   1158     84610 -0.013629
# 1997-09-29   1143   1172   1143   1162     48510  0.003454
# ...           ...    ...    ...    ...       ...       ...
# 2021-10-13  68700  69600  68300  68800  24172015 -0.002899
# 2021-10-14  69000  69800  68800  69400  19520641  0.008721
# 2021-10-15  70200  71000  70000  70100  18051612  0.010086
# 2021-10-18  70200  70300  69200  70200  13486391  0.001427
# 2021-10-19  70800  71000  70400  70600   9472565  0.005698
#
# [6000 rows x 6 columns]

# %%
## 연월일 생성
stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6000 entries, 1997-09-24 to 2021-10-19
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    6000 non-null   int64
#  1   High    6000 non-null   int64
#  2   Low     6000 non-null   int64
#  3   Close   6000 non-null   int64
#  4   Volume  6000 non-null   int64
#  5   Change  5999 non-null   float64
# dtypes: float64(1), int64(5)
# memory usage: 328.1 KB

# %%
stock['year'] = stock.index.year
stock['month'] = stock.index.month
stock['day'] = stock.index.day
stock
# Out:
#              Open   High    Low  Close    Volume    Change  year  month  day
# Date
# 1997-09-24   1186   1213   1165   1194     93880       NaN  1997      9   24
# 1997-09-25   1193   1193   1170   1179     70400 -0.012563  1997      9   25
# 1997-09-26   1170   1179   1161   1174     70500 -0.004241  1997      9   26
# 1997-09-27   1170   1170   1152   1158     84610 -0.013629  1997      9   27
# 1997-09-29   1143   1172   1143   1162     48510  0.003454  1997      9   29
# ...           ...    ...    ...    ...       ...       ...   ...    ...  ...
# 2021-10-13  68700  69600  68300  68800  24172015 -0.002899  2021     10   13
# 2021-10-14  69000  69800  68800  69400  19520641  0.008721  2021     10   14
# 2021-10-15  70200  71000  70000  70100  18051612  0.010086  2021     10   15
# 2021-10-18  70200  70300  69200  70200  13486391  0.001427  2021     10   18
# 2021-10-19  70800  71000  70400  70600   9472565  0.005698  2021     10   19
#
# [6000 rows x 9 columns]

# %%
stock.groupby(['year', 'month']).mean()
# Out:
#                     Open          High           Low         Close  \
# year month
# 1997 9       1170.500000   1187.000000   1158.666667   1175.833333
#      10      1027.230769   1045.730769    995.307692   1014.000000
#      11       796.280000    817.440000    769.240000    796.800000
#      12       748.590909    778.318182    723.409091    751.136364
# 1998 1       1107.272727   1133.727273   1072.454545   1116.136364
# ...                  ...           ...           ...           ...
# 2021 6      81195.454545  81590.909091  80740.909091  81104.545455
#      7      79645.454545  79963.636364  79250.000000  79577.272727
#      8      77204.761905  77914.285714  76428.571429  77023.809524
#      9      76526.315789  76884.210526  75800.000000  76305.263158
#      10     71181.818182  71536.363636  70336.363636  70718.181818
#
#                   Volume    Change        day
# year month
# 1997 9      7.184500e+04 -0.000921  26.833333
#      10     1.376285e+05 -0.020538  16.576923
#      11     4.078504e+05  0.005632  15.400000
#      12     5.538657e+05 -0.002667  13.318182
# 1998 1      7.167191e+05  0.040711  15.954545
# ...                  ...       ...        ...
# 2021 6      1.514088e+07  0.000147  15.318182
#      7      1.254028e+07 -0.001228  16.045455
#      8      2.380298e+07 -0.000968  15.952381
#      9      1.480175e+07 -0.001751  14.842105
#      10     1.838235e+07 -0.004308  10.727273
#
# [290 rows x 7 columns]

# %%
## 시각화
df = fdr.DataReader(search_num)
plt.figure(figsize=(16,9))
df['Close'].plot()
plt.show()

# %%
plt.figure(figsize=(16,9))
sns.lineplot(y=stock['Close'], x=stock.index)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Close'>

# %%
# 1990~2000, 2000~2010, 2010~2015, 2015~2020
time_steps = [['1990', '2000'], 
              ['2000', '2010'], 
              ['2010', '2015'], 
              ['2015', '2020']]

fig, axes = plt.subplots(2, 2)
fig.set_size_inches(16, 9)
for i in range(4):
    ax = axes[i//2, i%2]
    df = stock.loc[(stock.index > time_steps[i][0]) & (stock.index < time_steps[i][1])]
    sns.lineplot(y=df['Close'], x=df.index, ax=ax)
    ax.set_title(f'{time_steps[i][0]}~{time_steps[i][1]}')
    ax.set_xlabel('time')
    ax.set_ylabel('price')
plt.tight_layout()
plt.show()

# %%
## 데이터의 전처리
from sklearn.preprocessing import MinMaxScaler
cols = ['Open', 'High', 'Low', 'Close', 'Volume']

scaler = MinMaxScaler()
scaled = scaler.fit_transform(stock[cols])
scaled
# Out:
# array([[1.31339978e-02, 1.25309917e-02, 1.30167598e-02, 6.27399776e-03,
#         1.03957451e-03],
#        [1.32115172e-02, 1.23243802e-02, 1.30726257e-02, 6.10801899e-03,
#         7.79570151e-04],
#        [1.29568106e-02, 1.21797521e-02, 1.29720670e-02, 6.05269273e-03,
#         7.80677495e-04],
#        ...,
#        [7.77408638e-01, 7.33471074e-01, 7.82122905e-01, 7.68736238e-01,
#         1.99893436e-01],
#        [7.77408638e-01, 7.26239669e-01, 7.73184358e-01, 7.69842763e-01,
#         1.49340737e-01],
#        [7.84053156e-01, 7.33471074e-01, 7.86592179e-01, 7.74268863e-01,
#         1.04893877e-01]])

# %%
# 스케일 자료를 새로운 데이터 프레임으로 제작
df1 = pd.DataFrame(scaled, columns=cols)
df1
# Out:
#           Open      High       Low     Close    Volume
# 0     0.013134  0.012531  0.013017  0.006274  0.001040
# 1     0.013212  0.012324  0.013073  0.006108  0.000780
# 2     0.012957  0.012180  0.012972  0.006053  0.000781
# 3     0.012957  0.012087  0.012872  0.005876  0.000937
# 4     0.012658  0.012107  0.012771  0.005920  0.000537
# ...        ...       ...       ...       ...       ...
# 5995  0.760797  0.719008  0.763128  0.754351  0.267667
# 5996  0.764120  0.721074  0.768715  0.760991  0.216161
# 5997  0.777409  0.733471  0.782123  0.768736  0.199893
# 5998  0.777409  0.726240  0.773184  0.769843  0.149341
# 5999  0.784053  0.733471  0.786592  0.774269  0.104894
#
# [6000 rows x 5 columns]

# %%
# 데이터 분할
# 시계열 자료는 섞어서 분할하면 안됨
x = df1.drop(['Close'], 1)
y = df1['Close']

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=777, shuffle=False) # shuffle=False 자료를 섞지 않음
x_train
# Out:
#           Open      High       Low    Volume
# 0     0.013134  0.012531  0.013017  0.001040
# 1     0.013212  0.012324  0.013073  0.000780
# 2     0.012957  0.012180  0.012972  0.000781
# 3     0.012957  0.012087  0.012872  0.000937
# 4     0.012658  0.012107  0.012771  0.000537
# ...        ...       ...       ...       ...
# 4795  0.355925  0.339876  0.357542  0.002160
# 4796  0.367885  0.343182  0.363352  0.002806
# 4797  0.365227  0.341322  0.364916  0.001718
# 4798  0.363455  0.341322  0.364916  0.001390
# 4799  0.365449  0.347314  0.366480  0.002944
#
# [4800 rows x 4 columns]

# %%
x_test
# Out:
#           Open      High       Low    Volume
# 4800  0.374308  0.350826  0.372961  0.004004
# 4801  0.371429  0.360950  0.374749  0.006320
# 4802  0.385382  0.362190  0.387263  0.003441
# 4803  0.381838  0.359091  0.381453  0.003400
# 4804  0.380288  0.358264  0.382346  0.001879
# ...        ...       ...       ...       ...
# 5995  0.760797  0.719008  0.763128  0.267667
# 5996  0.764120  0.721074  0.768715  0.216161
# 5997  0.777409  0.733471  0.782123  0.199893
# 5998  0.777409  0.726240  0.773184  0.149341
# 5999  0.784053  0.733471  0.786592  0.104894
#
# [1200 rows x 4 columns]

# %%
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (4800, 4) (4800,)
# (1200, 4) (1200,)

# %%
# ---------슬라이싱 하면서 자료 일정량 잘라서 갖고옴
import tensorflow as tf
def windowed_dataset(series, window_size, batch_size, shuffle):
    series = tf.expand_dims(series, axis=-1)
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size + 1, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size + 1))
    if shuffle:
        ds = ds.shuffle(1000)
    ds = ds.map(lambda w: (w[:-1], w[-1]))
    return ds.batch(batch_size).prefetch(1)

# %%
# ------------------------
WINDOW_SIZE=20
BATCH_SIZE=32

# trian_data는 학습용 데이터셋, test_data는 검증용 데이터셋 입니다.
# WINDOW_SIZE와 BATCH_SIZE를 각 데이터셋에 적용해주세요.
train_data = windowed_dataset(y_train, WINDOW_SIZE, BATCH_SIZE, True)
test_data = windowed_dataset(y_test, WINDOW_SIZE, BATCH_SIZE, False)

# %%
train_data
# Out:
# <PrefetchDataset shapes: ((None, None, 1), (None, 1)), types: (tf.float64, tf.float64)>

# %%
test_data
# Out:
# <PrefetchDataset shapes: ((None, None, 1), (None, 1)), types: (tf.float64, tf.float64)>

# %%
# ---------------------------
# X: (batch_size, window_size, feature)
# Y: (batch_size, feature)
for data in train_data.take(1):
    print(f'데이터셋(X) 구성(batch_size, window_size, feature갯수): {data[0].shape}')
    print(f'데이터셋(Y) 구성(batch_size, window_size, feature갯수): {data[1].shape}')
# Out:
# 데이터셋(X) 구성(batch_size, window_size, feature갯수): (32, 20, 1)
# 데이터셋(Y) 구성(batch_size, window_size, feature갯수): (32, 1)

# %%
# --------------------------------------------
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Conv1D, Lambda
from tensorflow.keras.losses import Huber
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.models import load_model

# %%
model = Sequential([
    # 1차원 feature map 생성합니다. filters는 32로, kernel_size는 5로 지정해주세요.
    Conv1D(filters=32, kernel_size=5,
           padding="causal",
           activation="relu",
           input_shape=[WINDOW_SIZE, 1]),
    # LSTM과 Dense 레이러를 사용해주세요. 활성함수는 각각 tanh와 relu로 지정합니다.
    LSTM(16, activation='relu'),
    Dense(16, activation="relu"),
    Dense(1),
])
# Out:
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
# -------------------------------------------
# Sequence 학습에 비교적 좋은 퍼포먼스를 내는 Huber()를 사용합니다.
loss = Huber()
optimizer = Adam(0.0005)
model.compile(loss=Huber(), optimizer=optimizer, metrics=['mse'])

# %%
# earlystopping은 10번 epoch통안 val_loss 개선이 없다면 학습을 멈춥니다.
earlystopping = EarlyStopping(monitor='val_loss', patience=10)
# val_loss 기준 체크포인터도 생성합니다.
filename = os.path.join('tmp', 'ckeckpointer.ckpt')
checkpoint = ModelCheckpoint(filename, 
                             save_weights_only=True, 
                             save_best_only=True, 
                             monitor='val_loss', 
                             verbose=1)

# %%
#------------------------------------------------------------
# callbacks로 앞에서 구현한 earlystopping과 checkpoint를 지정해주세요.
history = model.fit(train_data, 
                    validation_data=(test_data), 
                    epochs=50, 
                    callbacks=[checkpoint, earlystopping])
# Out:
# Epoch 1/50
# 150/150 [==============================] - 25s 98ms/step - loss: 2.0851e-04 - mse: 4.1702e-04 - val_loss: 0.0012 - val_mse: 0.0024
#
# Epoch 00001: val_loss improved from inf to 0.00120, saving model to tmp\ckeckpointer.ckpt
# Epoch 2/50
# 150/150 [==============================] - 13s 83ms/step - loss: 1.9961e-05 - mse: 3.9922e-05 - val_loss: 7.3220e-04 - val_mse: 0.0015
#
# Epoch 00002: val_loss improved from 0.00120 to 0.00073, saving model to tmp\ckeckpointer.ckpt
# Epoch 3/50
# 150/150 [==============================] - 12s 78ms/step - loss: 1.6466e-05 - mse: 3.2932e-05 - val_loss: 8.5675e-04 - val_mse: 0.0017
#
# Epoch 00003: val_loss did not improve from 0.00073
# Epoch 4/50
# 150/150 [==============================] - 12s 78ms/step - loss: 1.5812e-05 - mse: 3.1624e-05 - val_loss: 5.5354e-04 - val_mse: 0.0011
#
# Epoch 00004: val_loss improved from 0.00073 to 0.00055, saving model to tmp\ckeckpointer.ckpt
# Epoch 5/50
# 150/150 [==============================] - 12s 82ms/step - loss: 1.6672e-05 - mse: 3.3343e-05 - val_loss: 6.8067e-04 - val_mse: 0.0014
#
# Epoch 00005: val_loss did not improve from 0.00055
# Epoch 6/50
# 150/150 [==============================] - 12s 81ms/step - loss: 1.5287e-05 - mse: 3.0575e-05 - val_loss: 6.0971e-04 - val_mse: 0.0012
#
# Epoch 00006: val_loss did not improve from 0.00055
# Epoch 7/50
# 150/150 [==============================] - 12s 80ms/step - loss: 1.5155e-05 - mse: 3.0310e-05 - val_loss: 4.5870e-04 - val_mse: 9.1740e-04
#
# Epoch 00007: val_loss improved from 0.00055 to 0.00046, saving model to tmp\ckeckpointer.ckpt
# Epoch 8/50
# 150/150 [==============================] - 12s 82ms/step - loss: 1.5129e-05 - mse: 3.0259e-05 - val_loss: 7.1401e-04 - val_mse: 0.0014
#
# Epoch 00008: val_loss did not improve from 0.00046
# Epoch 9/50
# 150/150 [==============================] - 12s 79ms/step - loss: 1.5580e-05 - mse: 3.1160e-05 - val_loss: 3.3787e-04 - val_mse: 6.7574e-04
#
# Epoch 00009: val_loss improved from 0.00046 to 0.00034, saving model to tmp\ckeckpointer.ckpt
# Epoch 10/50
# 150/150 [==============================] - 12s 79ms/step - loss: 1.4878e-05 - mse: 2.9755e-05 - val_loss: 2.4556e-04 - val_mse: 4.9112e-04
#
# Epoch 00010: val_loss improved from 0.00034 to 0.00025, saving model to tmp\ckeckpointer.ckpt
# Epoch 11/50
# 150/150 [==============================] - 12s 80ms/step - loss: 1.4860e-05 - mse: 2.9721e-05 - val_loss: 3.4023e-04 - val_mse: 6.8046e-04
#
# Epoch 00011: val_loss did not improve from 0.00025
# Epoch 12/50
# 150/150 [==============================] - 12s 78ms/step - loss: 1.4481e-05 - mse: 2.8962e-05 - val_loss: 2.2912e-04 - val_mse: 4.5823e-04
#
# Epoch 00012: val_loss improved from 0.00025 to 0.00023, saving model to tmp\ckeckpointer.ckpt
# Epoch 13/50
# 150/150 [==============================] - 12s 77ms/step - loss: 1.3949e-05 - mse: 2.7897e-05 - val_loss: 2.1194e-04 - val_mse: 4.2389e-04
#
# Epoch 00013: val_loss improved from 0.00023 to 0.00021, saving model to tmp\ckeckpointer.ckpt
# Epoch 14/50
# 150/150 [==============================] - 12s 82ms/step - loss: 1.4337e-05 - mse: 2.8674e-05 - val_loss: 2.1264e-04 - val_mse: 4.2528e-04
#
# Epoch 00014: val_loss did not improve from 0.00021
# Epoch 15/50
# 150/150 [==============================] - 12s 82ms/step - loss: 1.5721e-05 - mse: 3.1441e-05 - val_loss: 1.9633e-04 - val_mse: 3.9266e-04
#
# Epoch 00015: val_loss improved from 0.00021 to 0.00020, saving model to tmp\ckeckpointer.ckpt
# Epoch 16/50
# 150/150 [==============================] - 13s 84ms/step - loss: 1.3247e-05 - mse: 2.6495e-05 - val_loss: 1.9908e-04 - val_mse: 3.9816e-04
#
# Epoch 00016: val_loss did not improve from 0.00020
# Epoch 17/50
# 150/150 [==============================] - 13s 86ms/step - loss: 1.3987e-05 - mse: 2.7974e-05 - val_loss: 1.5979e-04 - val_mse: 3.1958e-04
#
# Epoch 00017: val_loss improved from 0.00020 to 0.00016, saving model to tmp\ckeckpointer.ckpt
# Epoch 18/50
# 150/150 [==============================] - 12s 79ms/step - loss: 1.2876e-05 - mse: 2.5753e-05 - val_loss: 1.6009e-04 - val_mse: 3.2018e-04
#
# Epoch 00018: val_loss did not improve from 0.00016
# Epoch 19/50
# 150/150 [==============================] - 12s 78ms/step - loss: 1.3286e-05 - mse: 2.6573e-05 - val_loss: 1.4831e-04 - val_mse: 2.9661e-04
#
# Epoch 00019: val_loss improved from 0.00016 to 0.00015, saving model to tmp\ckeckpointer.ckpt
# Epoch 20/50
# 150/150 [==============================] - 12s 78ms/step - loss: 1.2798e-05 - mse: 2.5597e-05 - val_loss: 2.1390e-04 - val_mse: 4.2780e-04
#
# Epoch 00020: val_loss did not improve from 0.00015
# Epoch 21/50
# 150/150 [==============================] - 12s 77ms/step - loss: 1.3763e-05 - mse: 2.7526e-05 - val_loss: 1.5539e-04 - val_mse: 3.1078e-04
#
# Epoch 00021: val_loss did not improve from 0.00015
# Epoch 22/50
# 150/150 [==============================] - 11s 76ms/step - loss: 1.2429e-05 - mse: 2.4858e-05 - val_loss: 1.3430e-04 - val_mse: 2.6860e-04
#
# Epoch 00022: val_loss improved from 0.00015 to 0.00013, saving model to tmp\ckeckpointer.ckpt
# Epoch 23/50
# 150/150 [==============================] - 12s 78ms/step - loss: 1.3003e-05 - mse: 2.6006e-05 - val_loss: 1.2578e-04 - val_mse: 2.5156e-04
#
# Epoch 00023: val_loss improved from 0.00013 to 0.00013, saving model to tmp\ckeckpointer.ckpt
# Epoch 24/50
# 150/150 [==============================] - 12s 78ms/step - loss: 1.3354e-05 - mse: 2.6709e-05 - val_loss: 1.4392e-04 - val_mse: 2.8785e-04
#
# Epoch 00024: val_loss did not improve from 0.00013
# Epoch 25/50
# 150/150 [==============================] - 12s 78ms/step - loss: 1.3422e-05 - mse: 2.6845e-05 - val_loss: 1.7296e-04 - val_mse: 3.4592e-04
#
# Epoch 00025: val_loss did not improve from 0.00013
# Epoch 26/50
# 150/150 [==============================] - 12s 77ms/step - loss: 1.2248e-05 - mse: 2.4496e-05 - val_loss: 1.2441e-04 - val_mse: 2.4882e-04
#
# Epoch 00026: val_loss improved from 0.00013 to 0.00012, saving model to tmp\ckeckpointer.ckpt
# Epoch 27/50
# 150/150 [==============================] - 12s 78ms/step - loss: 1.1806e-05 - mse: 2.3612e-05 - val_loss: 1.5405e-04 - val_mse: 3.0810e-04
#
# Epoch 00027: val_loss did not improve from 0.00012
# Epoch 28/50
# 150/150 [==============================] - 12s 78ms/step - loss: 1.2531e-05 - mse: 2.5062e-05 - val_loss: 1.5444e-04 - val_mse: 3.0888e-04
#
# Epoch 00028: val_loss did not improve from 0.00012
# Epoch 29/50
# 150/150 [==============================] - 12s 78ms/step - loss: 1.2217e-05 - mse: 2.4434e-05 - val_loss: 1.3876e-04 - val_mse: 2.7751e-04
#
# Epoch 00029: val_loss did not improve from 0.00012
# Epoch 30/50
# 150/150 [==============================] - 12s 77ms/step - loss: 1.1952e-05 - mse: 2.3904e-05 - val_loss: 1.3788e-04 - val_mse: 2.7575e-04
#
# Epoch 00030: val_loss did not improve from 0.00012
# Epoch 31/50
# 150/150 [==============================] - 12s 79ms/step - loss: 1.1526e-05 - mse: 2.3053e-05 - val_loss: 1.1066e-04 - val_mse: 2.2133e-04
#
# Epoch 00031: val_loss improved from 0.00012 to 0.00011, saving model to tmp\ckeckpointer.ckpt
# Epoch 32/50
# 150/150 [==============================] - 12s 80ms/step - loss: 1.1378e-05 - mse: 2.2755e-05 - val_loss: 1.0971e-04 - val_mse: 2.1943e-04
#
# Epoch 00032: val_loss improved from 0.00011 to 0.00011, saving model to tmp\ckeckpointer.ckpt
# Epoch 33/50
# 150/150 [==============================] - 12s 81ms/step - loss: 1.1188e-05 - mse: 2.2376e-05 - val_loss: 2.1707e-04 - val_mse: 4.3415e-04
#
# Epoch 00033: val_loss did not improve from 0.00011
# Epoch 34/50
# 150/150 [==============================] - 12s 80ms/step - loss: 1.3360e-05 - mse: 2.6719e-05 - val_loss: 1.2829e-04 - val_mse: 2.5657e-04
#
# Epoch 00034: val_loss did not improve from 0.00011
# Epoch 35/50
# 150/150 [==============================] - 12s 79ms/step - loss: 1.1106e-05 - mse: 2.2212e-05 - val_loss: 1.1936e-04 - val_mse: 2.3871e-04
#
# Epoch 00035: val_loss did not improve from 0.00011
# Epoch 36/50
# 150/150 [==============================] - 12s 80ms/step - loss: 1.0542e-05 - mse: 2.1083e-05 - val_loss: 1.0870e-04 - val_mse: 2.1739e-04
#
# Epoch 00036: val_loss improved from 0.00011 to 0.00011, saving model to tmp\ckeckpointer.ckpt
# Epoch 37/50
# 150/150 [==============================] - 13s 87ms/step - loss: 1.0695e-05 - mse: 2.1389e-05 - val_loss: 1.7824e-04 - val_mse: 3.5648e-04
#
# Epoch 00037: val_loss did not improve from 0.00011
# Epoch 38/50
# 150/150 [==============================] - 13s 83ms/step - loss: 1.0469e-05 - mse: 2.0938e-05 - val_loss: 1.4803e-04 - val_mse: 2.9605e-04
#
# Epoch 00038: val_loss did not improve from 0.00011
# Epoch 39/50
# 150/150 [==============================] - 13s 89ms/step - loss: 1.0371e-05 - mse: 2.0743e-05 - val_loss: 9.6810e-05 - val_mse: 1.9362e-04
#
# Epoch 00039: val_loss improved from 0.00011 to 0.00010, saving model to tmp\ckeckpointer.ckpt
# Epoch 40/50
# 150/150 [==============================] - 14s 90ms/step - loss: 1.0915e-05 - mse: 2.1831e-05 - val_loss: 9.9039e-05 - val_mse: 1.9808e-04
#
# Epoch 00040: val_loss did not improve from 0.00010
# Epoch 41/50
# 150/150 [==============================] - 13s 87ms/step - loss: 1.1351e-05 - mse: 2.2701e-05 - val_loss: 9.2402e-05 - val_mse: 1.8480e-04
#
# Epoch 00041: val_loss improved from 0.00010 to 0.00009, saving model to tmp\ckeckpointer.ckpt
# Epoch 42/50
# 150/150 [==============================] - 13s 88ms/step - loss: 1.0434e-05 - mse: 2.0869e-05 - val_loss: 1.6221e-04 - val_mse: 3.2442e-04
#
# Epoch 00042: val_loss did not improve from 0.00009
# Epoch 43/50
# 150/150 [==============================] - 13s 86ms/step - loss: 1.0907e-05 - mse: 2.1814e-05 - val_loss: 9.5697e-05 - val_mse: 1.9139e-04
#
# Epoch 00043: val_loss did not improve from 0.00009
# Epoch 44/50
# 150/150 [==============================] - 13s 87ms/step - loss: 1.0638e-05 - mse: 2.1275e-05 - val_loss: 8.7198e-05 - val_mse: 1.7440e-04
#
# Epoch 00044: val_loss improved from 0.00009 to 0.00009, saving model to tmp\ckeckpointer.ckpt
# Epoch 45/50
# 150/150 [==============================] - 14s 93ms/step - loss: 9.8512e-06 - mse: 1.9702e-05 - val_loss: 1.4912e-04 - val_mse: 2.9824e-04
#
# Epoch 00045: val_loss did not improve from 0.00009
# Epoch 46/50
# 150/150 [==============================] - 12s 82ms/step - loss: 1.0884e-05 - mse: 2.1767e-05 - val_loss: 1.1689e-04 - val_mse: 2.3378e-04
#
# Epoch 00046: val_loss did not improve from 0.00009
# Epoch 47/50
# 150/150 [==============================] - 12s 82ms/step - loss: 1.0017e-05 - mse: 2.0035e-05 - val_loss: 1.7606e-04 - val_mse: 3.5213e-04
#
# Epoch 00047: val_loss did not improve from 0.00009
# Epoch 48/50
# 150/150 [==============================] - 12s 82ms/step - loss: 1.1722e-05 - mse: 2.3444e-05 - val_loss: 2.5555e-04 - val_mse: 5.1109e-04
#
# Epoch 00048: val_loss did not improve from 0.00009
# Epoch 49/50
# 150/150 [==============================] - 13s 88ms/step - loss: 9.3694e-06 - mse: 1.8739e-05 - val_loss: 2.3445e-04 - val_mse: 4.6890e-04
#
# Epoch 00049: val_loss did not improve from 0.00009
# Epoch 50/50
# 150/150 [==============================] - 13s 86ms/step - loss: 9.7105e-06 - mse: 1.9421e-05 - val_loss: 1.4063e-04 - val_mse: 2.8127e-04
#
# Epoch 00050: val_loss did not improve from 0.00009

# %%
pred = model.predict(test_data)
pred.shape
# Out:
# (1180, 1)

# %%
pred[-1]
# Out:
# array([0.7490676], dtype=float32)

# %%
#------------------------------------------------------------------
# 20일치의 데이터로 21일치를 예측하므로 test_data 사용시 이전 20일은 예측하지 않습니다.
# 따라서 y_test 데이터에 [20:]로 슬라이싱해주세요.
plt.figure(figsize=(12, 9))
plt.plot(np.asarray(y_test)[20:], label='actual')
plt.plot(pred, label='prediction')
plt.legend()
plt.show()

# %% [markdown]
# ## 예측해보기

# %%
def create_model():
    model_2 = Sequential([
        # 1차원 feature map 생성합니다. filters는 32로, kernel_size는 5로 지정해주세요.
        Conv1D(filters=32, kernel_size=5,
            padding="causal",
            activation="relu",
            input_shape=[WINDOW_SIZE, 1]),
        # LSTM과 Dense 레이러를 사용해주세요. 활성함수는 각각 tanh와 relu로 지정합니다.
        LSTM(16, activation='relu'),
        Dense(16, activation="relu"),
        Dense(1)
    ])

    # -------------------------------------------
    # Sequence 학습에 비교적 좋은 퍼포먼스를 내는 Huber()를 사용합니다.
    loss = Huber()
    optimizer = Adam(0.0005)
    model_2.compile(loss=Huber(), optimizer=optimizer, metrics=['mse'])
    return model_2

# %%
model2 = create_model()
model2.load_weights('tmp/ckeckpointer.ckpt')
# Out:
# WARNING:tensorflow:Layer lstm_16 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
pred2 = model2.predict(test_data)
pred2.shape
# Out:
# (1180, 1)

# %%
scaler.inverse_transform

# %%
import pandas as pd
tmp = [[70200, 70300, 69200, 13459095]]
tmp_s = pd.DataFrame(tmp, columns=["Open", "High", "Low", "Volume"])
tmp_s
ns = stock[["Open", "High", "Low", "Volume"]]
ns = ns.append(tmp_s)
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaled = scaler.fit_transform(ns)
td = scaled[-1]
td = pd.DataFrame([td], columns=["Open", "High", "Low", "Volume"])
td
# Out:
#        Open     High       Low    Volume
# 0  0.777409  0.72624  0.773184  0.149038

# %%
# ------------------------
WINDOW_SIZE=1
BATCH_SIZE=1

# trian_data는 학습용 데이터셋, test_data는 검증용 데이터셋 입니다.
# WINDOW_SIZE와 BATCH_SIZE를 각 데이터셋에 적용해주세요.

test_data2 = windowed_dataset(td, WINDOW_SIZE, BATCH_SIZE, False)
test_data2
# Out:
# <PrefetchDataset shapes: ((None, None, 4, 1), (None, 4, 1)), types: (tf.float64, tf.float64)>
