# %%
import json
import pandas as pd
import os

# %%
# 라벨링 파일 DF 로 변환 작업
# 작업 진행률 확인 tqdm_notebook 추가
from tqdm import tqdm_notebook 
path = 'data/test/개집표기 무단진입/[라벨]개집표기 무단진입_1/'
folder_list = os.listdir(path) # 폴더 이름 리스트화

# 최종 모든 라벨링 데이터 모음 데이터프레임
# df_raw = pd.DataFrame(index=range(0,), columns=['image', 'date', 'worker', 'height', 'width', 'task', 'type', 'region',
    #    'disease', 'crop', 'area', 'grow', 'risk', 'points', 'name']) # 폴더내용 저장할 빈 데이터프레임 생성


       
for folder_name in tqdm_notebook(folder_list):
    print(folder_name)
    file_list = os.listdir(f'{path}/{folder_name}/')
    for file_name in file_list:
        # 각 폴더별 라벨링을 위한 임시 데이터 프레임
    #     df = pd.DataFrame(index=range(0,), columns=['image', 'date', 'worker', 'height', 'width', 'task', 'type', 'region',
    #    'disease', 'crop', 'area', 'grow', 'risk', 'points']) # 폴더내용 저장할 빈 데이터프레임 생성
        with open(f'{path}/{folder_name}/{file_name}', 'r') as f:
            json_data = json.load(f)
            tmp = pd.DataFrame(json_data)
            tmp = tmp[['description', 'annotations']][:15]
            tmp['description'][8:15] = tmp['annotations'][8:15] # 데이터프레임 내용 병합
            del(tmp['annotations']) # 필요없는 열 삭제
            tmp = tmp.T # 전치
            df = df.append(tmp) # df에 추가
            df['name'] = folder_name[4:] # 구분을 위한 name 열 생성
            df_raw = df_raw.append(df) # 최종 데이터 프레임에 추가

df_raw

# %%
from tqdm import tqdm_notebook 
path = 'data/test/개집표기 무단진입/[라벨]개집표기 무단진입_1'
folder_list = os.listdir(path) # 폴더 이름 리스트화

# %%
folder_list
# Out:
# ['annotation_2248321.json',
#  'annotation_2248322.json',
#  'annotation_2248327.json',
#  'annotation_2248377.json',
#  'annotation_2248424.json',
#  'annotation_2248428.json',
#  'annotation_2248448.json',
#  'annotation_2248467.json',
#  'annotation_2248507.json',
#  'annotation_2248513.json',
#  'annotation_2248519.json',
#  'annotation_2248523.json',
#  'annotation_2248634.json',
#  'annotation_2248860.json',
#  'annotation_2248925.json',
#  'annotation_2249105.json',
#  'annotation_2249146.json',
#  'annotation_2249261.json',
#  'annotation_2249278.json',
#  'annotation_2249281.json',
#  'annotation_2249507.json',
#  'annotation_2249522.json',
#  'annotation_2249550.json',
#  'annotation_2951960.json',
#  'annotation_2952019.json',
#  'annotation_2969641.json',
#  'annotation_2985321.json',
#  'annotation_3037018.json',
#  'annotation_3037894.json',
#  'annotation_3037929.json',
#  'annotation_3039747.json',
#  'annotation_3303792.json',
#  'annotation_3305097.json',
#  'annotation_3307463.json',
#  'annotation_3345220.json',
#  'annotation_3345221.json',
#  'annotation_3346563.json',
#  'annotation_3351959.json',
#  'annotation_3356077.json',
#  'annotation_3357409.json']

# %%
for folder_name in tqdm_notebook(folder_list):
    with open(f'{path}/{folder_name}', 'r') as f:
                json_data = json.load(f)
                tmp = pd.DataFrame(json_data)
                tmp = tmp[['description', 'annotations']][:15]
                tmp['description'][8:15] = tmp['annotations'][8:15] # 데이터프레임 내용 병합
                del(tmp['annotations']) # 필요없는 열 삭제
                tmp = tmp.T # 전치
                df = df.append(tmp) # df에 추가
                df['name'] = folder_name[4:] # 구분을 위한 name 열 생성
                df_raw = df_raw.append(df) # 최종 데이터 프레임에 추가

    df_raw
# Out:
# <ipython-input-11-0473e9ef8cdf>:1: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for folder_name in tqdm_notebook(folder_list):
#   0%|          | 0/40 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-0473e9ef8cdf> in <module>
#       2     with open(f'{path}/{folder_name}', 'r') as f:
#       3                 json_data = json.load(f)
# ----> 4                 tmp = pd.DataFrame(json_data)
#       5                 tmp = tmp[['description', 'annotations']][:15]
#       6                 tmp['description'][8:15] = tmp['annotations'][8:15] # 데이터프레임 내용 병합
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     462         # TODO: can we get rid of the dt64tz special case above?
#     463
# --> 464     return arrays_to_mgr(
#     465         arrays, data_names, index, columns, dtype=dtype, typ=typ, consolidate=copy
#     466     )
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity, typ, consolidate)
#     117         # figure out the index, if necessary
#     118         if index is None:
# --> 119             index = _extract_index(arrays)
#     120         else:
#     121             index = ensure_index(index)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in _extract_index(data)
#     636
#     637             if have_dicts:
# --> 638                 raise ValueError(
#     639                     "Mixing dicts with non-Series may lead to ambiguous ordering."
#     640                 )
#
# ValueError: Mixing dicts with non-Series may lead to ambiguous ordering.

# %%
json_data
# Out:
# {'id': 2248321,
#  'file': 'video_2248321_2051363.mp4',
#  'metadata': {'width': 3840,
#   'height': 2160,
#   'duration': 320.93,
#   'fps': 30,
#   'frames': 9628,
#   'created': 'Mon Oct 19 11:51:36 2020'},
#  'frames': [{'number': 4847,
#    'image': 'frame_4847.jpg',
#    'annotations': [{'label': {'x': 0, 'y': 1245, 'width': 363, 'height': 807},
#      'category': {'code': 'child',
#       'attributes': [{'code': 'global_id', 'value': '7057'}]}},
#     {'label': {'x': 2447, 'y': 607, 'width': 255, 'height': 554},
#      'category': {'code': 'person', 'attributes': []}}]},
#   {'number': 4861,
#    'image': 'frame_4861.jpg',
#    'annotations': [{'label': {'x': 170,
#       'y': 1069,
#       'width': 305,
#       'height': 691},
#      'category': {'code': 'child',
#       'attributes': [{'code': 'global_id', 'value': '7057'}]}},
#     {'label': {'x': 2447, 'y': 613, 'width': 282, 'height': 547},
#      'category': {'code': 'person', 'attributes': []}}]},
#   {'number': 4876,
#    'image': 'frame_4876.jpg',
#    'annotations': [{'label': {'x': 425, 'y': 950, 'width': 251, 'height': 593},
#      'category': {'code': 'child',
#       'attributes': [{'code': 'global_id', 'value': '7057'}]}},
#     {'label': {'x': 2472, 'y': 611, 'width': 268, 'height': 550},
#      'category': {'code': 'person', 'attributes': []}}]},
#   {'number': 4891,
#    'image': 'frame_4891.jpg',
#    'annotations': [{'label': {'x': 763, 'y': 874, 'width': 167, 'height': 505},
#      'category': {'code': 'child',
#       'attributes': [{'code': 'global_id', 'value': '7057'}]}},
#     {'label': {'x': 2516, 'y': 607, 'width': 230, 'height': 551},
#      'category': {'code': 'person', 'attributes': []}}]},
#   {'number': 4906,
#    'image': 'frame_4906.jpg',
#    'annotations': [{'label': {'x': 1019,
#       'y': 814,
#       'width': 160,
#       'height': 448},
#      'category': {'code': 'child',
#       'attributes': [{'code': 'global_id', 'value': '7057'}]}},
#     {'label': {'x': 2548, 'y': 577, 'width': 294, 'height': 550},
#      'category': {'code': 'person', 'attributes': []}}]},
#   {'number': 4921,
#    'image': 'frame_4921.jpg',
#    'annotations': [{'label': {'x': 1187,
#       'y': 774,
#       'width': 159,
#       'height': 381},
#      'category': {'code': 'child',
#       'attributes': [{'code': 'global_id', 'value': '7057'}]}},
#     {'label': {'x': 2628, 'y': 569, 'width': 255, 'height': 439},
#      'category': {'code': 'person', 'attributes': []}}]},
#   {'number': 4936,
#    'image': 'frame_4936.jpg',
#    'annotations': [{'label': {'x': 1305,
#       'y': 732,
#       'width': 149,
#       'height': 358},
#      'category': {'code': 'child',
#       'attributes': [{'code': 'global_id', 'value': '7057'}]}},
#     {'label': {'x': 2699, 'y': 577, 'width': 256, 'height': 261},
#      'category': {'code': 'person', 'attributes': []}}]},
#   {'number': 4951,
#    'image': 'frame_4951.jpg',
#    'annotations': [{'label': {'x': 1396,
#       'y': 690,
#       'width': 144,
#       'height': 279},
#      'category': {'code': 'child',
#       'attributes': [{'code': 'global_id', 'value': '7057'}]}},
#     {'label': {'x': 2779, 'y': 566, 'width': 242, 'height': 273},
#      'category': {'code': 'person', 'attributes': []}}]},
#   {'number': 4966,
#    'image': 'frame_4966.jpg',
#    'annotations': [{'label': {'x': 1505,
#       'y': 666,
#       'width': 141,
#       'height': 269},
#      'category': {'code': 'child',
#       'attributes': [{'code': 'global_id', 'value': '7057'}]}},
#     {'label': {'x': 2874, 'y': 556, 'width': 214, 'height': 421},
#      'category': {'code': 'person', 'attributes': []}}]},
#   {'number': 4981,
#    'image': 'frame_4981.jpg',
#    'annotations': [{'label': {'x': 1583, 'y': 651, 'width': 94, 'height': 262},
#      'category': {'code': 'child',
#       'attributes': [{'code': 'global_id', 'value': '7057'}]}},
#     {'label': {'x': 2919, 'y': 542, 'width': 197, 'height': 404},
#      'category': {'code': 'person', 'attributes': []}}]},
#   {'number': 4996,
#    'image': 'frame_4996.jpg',
#    'annotations': [{'label': {'x': 1613, 'y': 642, 'width': 99, 'height': 273},
#      'category': {'code': 'child',
#       'attributes': [{'code': 'global_id', 'value': '7057'}]}},
#     {'label': {'x': 2927, 'y': 530, 'width': 192, 'height': 369},
#      'category': {'code': 'person', 'attributes': []}}]},
#   {'number': 5011,
#    'image': 'frame_5011.jpg',
#    'annotations': [{'label': {'x': 1571,
#       'y': 648,
#       'width': 143,
#       'height': 274},
#      'category': {'code': 'child',
#       'attributes': [{'code': 'global_id', 'value': '7057'}]}},
#     {'label': {'x': 2883, 'y': 518, 'width': 185, 'height': 371},
#      'category': {'code': 'person', 'attributes': []}}]},
#   {'number': 5026,
#    'image': 'frame_5026.jpg',
#    'annotations': [{'label': {'x': 1568,
#       'y': 656,
#       'width': 122,
#       'height': 268},
#      'category': {'code': 'child',
#       'attributes': [{'code': 'global_id', 'value': '7057'}]}},
#     {'label': {'x': 2835, 'y': 513, 'width': 180, 'height': 304},
#      'category': {'code': 'person', 'attributes': []}}]},
#   {'number': 5041,
#    'image': 'frame_5041.jpg',
#    'annotations': [{'label': {'x': 1576,
#       'y': 654,
#       'width': 133,
#       'height': 259},
#      'category': {'code': 'child',
#       'attributes': [{'code': 'global_id', 'value': '7057'}]}},
#     {'label': {'x': 2766, 'y': 505, 'width': 182, 'height': 293},
#      'category': {'code': 'person', 'attributes': []}}]},
#   {'number': 5056,
#    'image': 'frame_5056.jpg',
#    'annotations': [{'label': {'x': 1561,
#       'y': 652,
#       'width': 125,
#       'height': 266},
#      'category': {'code': 'child',
#       'attributes': [{'code': 'global_id', 'value': '7057'}]}},
#     {'label': {'x': 2730, 'y': 497, 'width': 178, 'height': 306},
#      'category': {'code': 'person', 'attributes': []}}]},
#   {'number': 5071,
#    'image': 'frame_5071.jpg',
#    'annotations': [{'label': {'x': 1560,
#       'y': 645,
#       'width': 104,
#       'height': 270},
#      'category': {'code': 'child',
#       'attributes': [{'code': 'global_id', 'value': '7057'}]}},
#     {'label': {'x': 2690, 'y': 492, 'width': 145, 'height': 306},
#      'category': {'code': 'person', 'attributes': []}}]},
#   {'number': 5086,
#    'image': 'frame_5086.jpg',
#    'annotations': [{'label': {'x': 1573, 'y': 637, 'width': 92, 'height': 271},
#      'category': {'code': 'child',
#       'attributes': [{'code': 'global_id', 'value': '7057'}]}},
#     {'label': {'x': 2625, 'y': 484, 'width': 157, 'height': 293},
#      'category': {'code': 'person', 'attributes': []}}]},
#   {'number': 5101,
#    'image': 'frame_5101.jpg',
#    'annotations': [{'label': {'x': 1593, 'y': 626, 'width': 78, 'height': 275},
#      'category': {'code': 'child',
#       'attributes': [{'code': 'global_id', 'value': '7057'}]}},
#     {'label': {'x': 2614, 'y': 479, 'width': 97, 'height': 277},
#      'category': {'code': 'person', 'attributes': []}}]},
#   {'number': 5116,
#    'image': 'frame_5116.jpg',
#    'annotations': [{'label': {'x': 1620,
#       'y': 620,
#       'width': 111,
#       'height': 278},
#      'category': {'code': 'child',
#       'attributes': [{'code': 'global_id', 'value': '7057'}]}}]},
#   {'number': 5131,
#    'image': 'frame_5131.jpg',
#    'annotations': [{'label': {'x': 1627, 'y': 619, 'width': 40, 'height': 208},
#      'category': {'code': 'child',
#       'attributes': [{'code': 'global_id', 'value': '7057'}]}}]},
#   {'number': 5146,
#    'image': 'frame_5146.jpg',
#    'annotations': [{'label': {'x': 1579, 'y': 626, 'width': 88, 'height': 264},
#      'category': {'code': 'child',
#       'attributes': [{'code': 'global_id', 'value': '7057'}]}}]},
#   {'number': 5161,
#    'image': 'frame_5161.jpg',
#    'annotations': [{'label': {'x': 1708, 'y': 624, 'width': 71, 'height': 252},
#      'category': {'code': 'child',
#       'attributes': [{'code': 'global_id', 'value': '7057'}]}},
#     {'label': {'x': 2318, 'y': 459, 'width': 73, 'height': 247},
#      'category': {'code': 'person', 'attributes': []}}]},
#   {'number': 5176,
#    'image': 'frame_5176.jpg',
#    'annotations': [{'label': {'x': 2243,
#       'y': 455,
#       'width': 134,
#       'height': 240},
#      'category': {'code': 'person', 'attributes': []}}]},
#   {'number': 5191,
#    'image': 'frame_5191.jpg',
#    'annotations': [{'label': {'x': 2208,
#       'y': 454,
#       'width': 128,
#       'height': 232},
#      'category': {'code': 'person', 'attributes': []}}]},
#   {'number': 5206,
#    'image': 'frame_5206.jpg',
#    'annotations': [{'label': {'x': 2091, 'y': 625, 'width': 39, 'height': 98},
#      'category': {'code': 'child',
#       'attributes': [{'code': 'global_id', 'value': '7057'}]}},
#     {'label': {'x': 2140, 'y': 450, 'width': 126, 'height': 225},
#      'category': {'code': 'person', 'attributes': []}}]},
#   {'number': 5221,
#    'image': 'frame_5221.jpg',
#    'annotations': [{'label': {'x': 2098,
#       'y': 448,
#       'width': 101,
#       'height': 223},
#      'category': {'code': 'person', 'attributes': []}},
#     {'label': {'x': 2098, 'y': 560, 'width': 85, 'height': 180},
#      'category': {'code': 'child',
#       'attributes': [{'code': 'global_id', 'value': '7057'}]}}]},
#   {'number': 5236,
#    'image': 'frame_5236.jpg',
#    'annotations': [{'label': {'x': 2118, 'y': 543, 'width': 77, 'height': 192},
#      'category': {'code': 'child',
#       'attributes': [{'code': 'global_id', 'value': '7057'}]}}]},
#   {'number': 5251,
#    'image': 'frame_5251.jpg',
#    'annotations': [{'label': {'x': 2112, 'y': 540, 'width': 73, 'height': 184},
#      'category': {'code': 'child',
#       'attributes': [{'code': 'global_id', 'value': '7057'}]}}]},
#   {'number': 5266,
#    'image': 'frame_5266.jpg',
#    'annotations': [{'label': {'x': 2098, 'y': 525, 'width': 54, 'height': 180},
#      'category': {'code': 'child',
#       'attributes': [{'code': 'global_id', 'value': '7057'}]}}]}]}

# %%
# 라벨링 파일 DF 로 변환 작업
# 작업 진행률 확인 tqdm_notebook 추가
from tqdm import tqdm_notebook 
path = 'D:/멀티모달/멀티모달_분야/KETI_MULTIMODAL_0000000012'
folder_list = os.listdir(path) # 폴더 이름 리스트화

# %%
folder_list
# Out:
# ['KETI_MULTIMODAL_0000000012',
#  'KETI_MULTIMODAL_0000000012.mp4',
#  'KETI_MULTIMODAL_0000000012_interpolation.json',
#  'KETI_MULTIMODAL_0000000012_jiyu.json',
#  'KETI_MULTIMODAL_0000000012_jiyu_interpolation.json',
#  'KETI_MULTIMODAL_0000000012_roykim1234.json',
#  'KETI_MULTIMODAL_0000000012_roykim1234_interpolation.json']

# %%
# 최종 모든 라벨링 데이터 모음 데이터프레임
# df_raw = pd.DataFrame(index=range(0,), columns=['image', 'date', 'worker', 'height', 'width', 'task', 'type', 'region',
    #    'disease', 'crop', 'area', 'grow', 'risk', 'points', 'name']) # 폴더내용 저장할 빈 데이터프레임 생성


       
for folder_name in tqdm_notebook(folder_list):
    if 'json' in folder_name:
        with open(f'{path}/{folder_name}', 'r', encoding='utf-8') as f:
            json_data = json.load(f)
# Out:
# <ipython-input-8-0f053f692c7b>:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for folder_name in tqdm_notebook(folder_list):
#   0%|          | 0/7 [00:00<?, ?it/s]

# %%
json_data
# Out:
# {'common_info': {'shot_folder': 'KETI_MULTIMODAL_0000000012',
#   'video_file': 'KETI_MULTIMODAL_0000000012.mp4',
#   'file_id': 'KETI_MULTIMODAL_0000000012',
#   'frame_size': 493,
#   'clip_descs': []},
#  'shot_infos': [{'image_folder': 'KETI_SHOT_0000145756',
#    'visual_infos': [{'image_id': 'KM_0000000448.jpg',
#      'frame_id': 448,
#      'place': 'restaurant',
#      'persons': [],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 20,
#         'min_y': 56,
#         'max_x': 1083,
#         'max_y': 1057}},
#       {'object_id': 'person',
#        'object_rect': {'min_x': 1357,
#         'min_y': 148,
#         'max_x': 1896,
#         'max_y': 1059}}],
#      'image_descs': ['남자들이 있다',
#       '남자들은 서로 쳐다보고있다',
#       '남자는 검정머리이다',
#       '남자는 흰 셔츠를 입고있다',
#       '남자는 옆을 보고있다']},
#     {'image_id': 'KM_0000000449.jpg',
#      'frame_id': 449,
#      'place': 'restaurant',
#      'persons': [],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 18,
#         'min_y': 55,
#         'max_x': 1081,
#         'max_y': 1057}},
#       {'object_id': 'person',
#        'object_rect': {'min_x': 1341,
#         'min_y': 155,
#         'max_x': 1870,
#         'max_y': 1047}}],
#      'image_descs': ['남자들이 있다',
#       '남자들은 서로 쳐다보고있다',
#       '남자는 검정머리이다',
#       '남자는 흰 셔츠를 입고있다',
#       '남자는 옆을 보고있다']},
#     {'image_id': 'KM_0000000450.jpg',
#      'frame_id': 450,
#      'place': 'restaurant',
#      'persons': [],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 24,
#         'min_y': 59,
#         'max_x': 1087,
#         'max_y': 1061}},
#       {'object_id': 'person',
#        'object_rect': {'min_x': 1320,
#         'min_y': 162,
#         'max_x': 1839,
#         'max_y': 1037}}],
#      'image_descs': ['남자들이 있다',
#       '남자들은 서로 쳐다보고있다',
#       '남자는 검정머리이다',
#       '남자는 흰 셔츠를 입고있다',
#       '남자는 옆을 보고있다']},
#     {'image_id': 'KM_0000000451.jpg',
#      'frame_id': 451,
#      'place': 'restaurant',
#      'persons': [],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 37,
#         'min_y': 63,
#         'max_x': 1100,
#         'max_y': 1064}},
#       {'object_id': 'person',
#        'object_rect': {'min_x': 1299,
#         'min_y': 162,
#         'max_x': 1818,
#         'max_y': 1037}}],
#      'image_descs': ['남자들이 있다',
#       '남자들은 서로 쳐다보고있다',
#       '남자는 검정머리이다',
#       '남자는 흰 셔츠를 입고있다',
#       '남자는 옆을 보고있다']},
#     {'image_id': 'KM_0000000452.jpg',
#      'frame_id': 452,
#      'place': 'restaurant',
#      'persons': [],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 35,
#         'min_y': 63,
#         'max_x': 1098,
#         'max_y': 1065}},
#       {'object_id': 'person',
#        'object_rect': {'min_x': 1305,
#         'min_y': 169,
#         'max_x': 1813,
#         'max_y': 1027}}],
#      'image_descs': ['남자들이 있다',
#       '남자들은 서로 쳐다보고있다',
#       '남자는 검정머리이다',
#       '남자는 흰 셔츠를 입고있다',
#       '남자는 옆을 보고있다']},
#     {'image_id': 'KM_0000000453.jpg',
#      'frame_id': 453,
#      'place': 'restaurant',
#      'persons': [],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 43,
#         'min_y': 67,
#         'max_x': 1106,
#         'max_y': 1068}},
#       {'object_id': 'person',
#        'object_rect': {'min_x': 1276,
#         'min_y': 174,
#         'max_x': 1784,
#         'max_y': 1031}}],
#      'image_descs': ['남자들이 있다',
#       '남자들은 서로 쳐다보고있다',
#       '남자는 검정머리이다',
#       '남자는 흰 셔츠를 입고있다',
#       '남자는 옆을 보고있다']},
#     {'image_id': 'KM_0000000454.jpg',
#      'frame_id': 454,
#      'place': 'restaurant',
#      'persons': [],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 55,
#         'min_y': 74,
#         'max_x': 1119,
#         'max_y': 1075}},
#       {'object_id': 'person',
#        'object_rect': {'min_x': 1261,
#         'min_y': 174,
#         'max_x': 1769,
#         'max_y': 1032}}],
#      'image_descs': ['남자들이 있다',
#       '남자들은 서로 쳐다보고있다',
#       '남자는 검정머리이다',
#       '남자는 흰 셔츠를 입고있다',
#       '남자는 옆을 보고있다']},
#     {'image_id': 'KM_0000000455.jpg',
#      'frame_id': 455,
#      'place': 'restaurant',
#      'persons': [],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 80,
#         'min_y': 88,
#         'max_x': 1123,
#         'max_y': 1070}},
#       {'object_id': 'person',
#        'object_rect': {'min_x': 1238,
#         'min_y': 184,
#         'max_x': 1736,
#         'max_y': 1025}}],
#      'image_descs': ['남자들이 있다',
#       '남자들은 서로 쳐다보고있다',
#       '남자는 검정머리이다',
#       '남자는 흰 셔츠를 입고있다',
#       '남자는 옆을 보고있다']},
#     {'image_id': 'KM_0000000456.jpg',
#      'frame_id': 456,
#      'place': 'restaurant',
#      'persons': [],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 80,
#         'min_y': 88,
#         'max_x': 1123,
#         'max_y': 1070}},
#       {'object_id': 'person',
#        'object_rect': {'min_x': 1238,
#         'min_y': 184,
#         'max_x': 1736,
#         'max_y': 1025}}],
#      'image_descs': ['남자들이 있다',
#       '남자들은 서로 쳐다보고있다',
#       '남자는 검정머리이다',
#       '남자는 흰 셔츠를 입고있다',
#       '남자는 옆을 보고있다']},
#     {'image_id': 'KM_0000000457.jpg',
#      'frame_id': 457,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 1526,
#          'min_y': 329,
#          'max_x': 1969,
#          'max_y': 858},
#         'full_rect': {'min_x': 1069,
#          'min_y': 138,
#          'max_x': 2116,
#          'max_y': 1029},
#         'behavior': 'none',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 0,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 10},
#         'person_descs': '박선호는 말을 듣고있다'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 115,
#         'min_y': 156,
#         'max_x': 1180,
#         'max_y': 988}}],
#      'image_descs': ['남자들은 대화중이다',
#       '남자들은 머리가 까맣다',
#       '남자들은 가까이 있다',
#       '뒤에 빨간 불빛이 비친다',
#       '남자들은 셔츠를 입고있다']},
#     {'image_id': 'KM_0000000458.jpg',
#      'frame_id': 458,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 1526,
#          'min_y': 329,
#          'max_x': 1969,
#          'max_y': 858},
#         'full_rect': {'min_x': 1069,
#          'min_y': 138,
#          'max_x': 2116,
#          'max_y': 1029},
#         'behavior': 'none',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 0,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 10},
#         'person_descs': '박선호는 말을 듣고있다'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 115,
#         'min_y': 156,
#         'max_x': 1180,
#         'max_y': 988}}],
#      'image_descs': ['남자들은 대화중이다',
#       '남자들은 머리가 까맣다',
#       '남자들은 가까이 있다',
#       '뒤에 빨간 불빛이 비친다',
#       '남자들은 셔츠를 입고있다']},
#     {'image_id': 'KM_0000000459.jpg',
#      'frame_id': 459,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 1527,
#          'min_y': 331,
#          'max_x': 1971,
#          'max_y': 860},
#         'full_rect': {'min_x': 1098,
#          'min_y': 170,
#          'max_x': 2086,
#          'max_y': 1010},
#         'behavior': 'none',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 0,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 10},
#         'person_descs': '박선호는 말을 듣고있다'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 114,
#         'min_y': 153,
#         'max_x': 1179,
#         'max_y': 985}}],
#      'image_descs': ['남자들은 대화중이다',
#       '남자들은 머리가 까맣다',
#       '남자들은 가까이 있다',
#       '뒤에 빨간 불빛이 비친다',
#       '남자들은 셔츠를 입고있다']},
#     {'image_id': 'KM_0000000460.jpg',
#      'frame_id': 460,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 1501,
#          'min_y': 333,
#          'max_x': 1945,
#          'max_y': 862},
#         'full_rect': {'min_x': 1047,
#          'min_y': 148,
#          'max_x': 2094,
#          'max_y': 1039},
#         'behavior': 'none',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 0,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 10},
#         'person_descs': '박선호는 말을 듣고있다'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 152,
#         'min_y': 169,
#         'max_x': 1196,
#         'max_y': 984}}],
#      'image_descs': ['남자들은 대화중이다',
#       '남자들은 머리가 까맣다',
#       '남자들은 가까이 있다',
#       '뒤에 빨간 불빛이 비친다',
#       '남자들은 셔츠를 입고있다']},
#     {'image_id': 'KM_0000000461.jpg',
#      'frame_id': 461,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 1479,
#          'min_y': 343,
#          'max_x': 1914,
#          'max_y': 861},
#         'full_rect': {'min_x': 1002,
#          'min_y': 142,
#          'max_x': 2070,
#          'max_y': 1050},
#         'behavior': 'none',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 0,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 10},
#         'person_descs': '박선호는 말을 듣고있다'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 162,
#         'min_y': 168,
#         'max_x': 1227,
#         'max_y': 999}}],
#      'image_descs': ['남자들은 대화중이다',
#       '남자들은 머리가 까맣다',
#       '남자들은 가까이 있다',
#       '뒤에 빨간 불빛이 비친다',
#       '남자들은 셔츠를 입고있다']},
#     {'image_id': 'KM_0000000462.jpg',
#      'frame_id': 462,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 1450,
#          'min_y': 347,
#          'max_x': 1885,
#          'max_y': 865},
#         'full_rect': {'min_x': 995,
#          'min_y': 155,
#          'max_x': 2043,
#          'max_y': 1046},
#         'behavior': 'none',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 0,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 10},
#         'person_descs': '박선호는 말을 듣고있다'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 184,
#         'min_y': 171,
#         'max_x': 1249,
#         'max_y': 1003}}],
#      'image_descs': ['남자들은 대화중이다',
#       '남자들은 머리가 까맣다',
#       '남자들은 가까이 있다',
#       '뒤에 빨간 불빛이 비친다',
#       '남자들은 셔츠를 입고있다']},
#     {'image_id': 'KM_0000000463.jpg',
#      'frame_id': 463,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 1420,
#          'min_y': 349,
#          'max_x': 1855,
#          'max_y': 868},
#         'full_rect': {'min_x': 945,
#          'min_y': 151,
#          'max_x': 2014,
#          'max_y': 1059},
#         'behavior': 'none',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 0,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 10},
#         'person_descs': '박선호는 말을 듣고있다'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 204,
#         'min_y': 175,
#         'max_x': 1269,
#         'max_y': 1007}}],
#      'image_descs': ['남자들은 대화중이다',
#       '남자들은 머리가 까맣다',
#       '남자들은 가까이 있다',
#       '뒤에 빨간 불빛이 비친다',
#       '남자들은 셔츠를 입고있다']},
#     {'image_id': 'KM_0000000464.jpg',
#      'frame_id': 464,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 1419,
#          'min_y': 349,
#          'max_x': 1854,
#          'max_y': 868},
#         'full_rect': {'min_x': 951,
#          'min_y': 153,
#          'max_x': 2020,
#          'max_y': 1061},
#         'behavior': 'none',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 0,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 10},
#         'person_descs': '박선호는 말을 듣고있다'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 208,
#         'min_y': 179,
#         'max_x': 1273,
#         'max_y': 1011}}],
#      'image_descs': ['남자들은 대화중이다',
#       '남자들은 머리가 까맣다',
#       '남자들은 가까이 있다',
#       '뒤에 빨간 불빛이 비친다',
#       '남자들은 셔츠를 입고있다']},
#     {'image_id': 'KM_0000000465.jpg',
#      'frame_id': 465,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 1391,
#          'min_y': 357,
#          'max_x': 1817,
#          'max_y': 866},
#         'full_rect': {'min_x': 915,
#          'min_y': 155,
#          'max_x': 1984,
#          'max_y': 1064},
#         'behavior': 'none',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 0,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 10},
#         'person_descs': '박선호는 말을 듣고있다'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 216,
#         'min_y': 180,
#         'max_x': 1281,
#         'max_y': 1011}}],
#      'image_descs': ['남자들은 대화중이다',
#       '남자들은 머리가 까맣다',
#       '남자들은 가까이 있다',
#       '뒤에 빨간 불빛이 비친다',
#       '남자들은 셔츠를 입고있다']},
#     {'image_id': 'KM_0000000466.jpg',
#      'frame_id': 466,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 1362,
#          'min_y': 365,
#          'max_x': 1781,
#          'max_y': 864},
#         'full_rect': {'min_x': 888,
#          'min_y': 156,
#          'max_x': 1956,
#          'max_y': 1064},
#         'behavior': 'none',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 0,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 10},
#         'person_descs': '박선호는 말을 듣고있다'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 212,
#         'min_y': 179,
#         'max_x': 1277,
#         'max_y': 1011}}],
#      'image_descs': ['남자들은 대화중이다',
#       '남자들은 머리가 까맣다',
#       '남자들은 가까이 있다',
#       '뒤에 빨간 불빛이 비친다',
#       '남자들은 셔츠를 입고있다']},
#     {'image_id': 'KM_0000000467.jpg',
#      'frame_id': 467,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 1300,
#          'min_y': 374,
#          'max_x': 1710,
#          'max_y': 863},
#         'full_rect': {'min_x': 839,
#          'min_y': 157,
#          'max_x': 1907,
#          'max_y': 1066},
#         'behavior': 'none',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 0,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 10},
#         'person_descs': '박선호는 말을 듣고있다'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 179,
#         'min_y': 164,
#         'max_x': 1244,
#         'max_y': 996}}],
#      'image_descs': ['남자들은 대화중이다',
#       '남자들은 머리가 까맣다',
#       '남자들은 가까이 있다',
#       '뒤에 빨간 불빛이 비친다',
#       '남자들은 셔츠를 입고있다']},
#     {'image_id': 'KM_0000000468.jpg',
#      'frame_id': 468,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 1269,
#          'min_y': 377,
#          'max_x': 1679,
#          'max_y': 866},
#         'full_rect': {'min_x': 813,
#          'min_y': 155,
#          'max_x': 1882,
#          'max_y': 1063},
#         'behavior': 'none',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 0,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 10},
#         'person_descs': '박선호는 말을 듣고있다'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 183,
#         'min_y': 179,
#         'max_x': 1227,
#         'max_y': 995}}],
#      'image_descs': ['남자들은 대화중이다',
#       '남자들은 머리가 까맣다',
#       '남자들은 가까이 있다',
#       '뒤에 빨간 불빛이 비친다',
#       '남자들은 셔츠를 입고있다']},
#     {'image_id': 'KM_0000000469.jpg',
#      'frame_id': 469,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 1238,
#          'min_y': 379,
#          'max_x': 1648,
#          'max_y': 868},
#         'full_rect': {'min_x': 797,
#          'min_y': 164,
#          'max_x': 1845,
#          'max_y': 1055},
#         'behavior': 'none',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 0,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 10},
#         'person_descs': '박선호는 말을 듣고있다'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 163,
#         'min_y': 177,
#         'max_x': 1208,
#         'max_y': 992}}],
#      'image_descs': ['남자들은 대화중이다',
#       '남자들은 머리가 까맣다',
#       '남자들은 가까이 있다',
#       '뒤에 빨간 불빛이 비친다',
#       '남자들은 셔츠를 입고있다']},
#     {'image_id': 'KM_0000000470.jpg',
#      'frame_id': 470,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 1210,
#          'min_y': 382,
#          'max_x': 1620,
#          'max_y': 871},
#         'full_rect': {'min_x': 788,
#          'min_y': 179,
#          'max_x': 1795,
#          'max_y': 1035},
#         'behavior': 'none',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 0,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 10},
#         'person_descs': '박선호는 말을 듣고있다'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 134,
#         'min_y': 168,
#         'max_x': 1199,
#         'max_y': 1000}}],
#      'image_descs': ['남자들은 대화중이다',
#       '남자들은 머리가 까맣다',
#       '남자들은 가까이 있다',
#       '뒤에 빨간 불빛이 비친다',
#       '남자들은 셔츠를 입고있다']},
#     {'image_id': 'KM_0000000471.jpg',
#      'frame_id': 471,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 1183,
#          'min_y': 384,
#          'max_x': 1593,
#          'max_y': 873},
#         'full_rect': {'min_x': 757,
#          'min_y': 176,
#          'max_x': 1764,
#          'max_y': 1032},
#         'behavior': 'none',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 0,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 10},
#         'person_descs': '박선호는 말을 듣고있다'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 111,
#         'min_y': 164,
#         'max_x': 1176,
#         'max_y': 996}}],
#      'image_descs': ['남자들은 대화중이다',
#       '남자들은 머리가 까맣다',
#       '남자들은 가까이 있다',
#       '뒤에 빨간 불빛이 비친다',
#       '남자들은 셔츠를 입고있다']},
#     {'image_id': 'KM_0000000472.jpg',
#      'frame_id': 472,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 1185,
#          'min_y': 385,
#          'max_x': 1595,
#          'max_y': 874},
#         'full_rect': {'min_x': 767,
#          'min_y': 185,
#          'max_x': 1754,
#          'max_y': 1025},
#         'behavior': 'none',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 0,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 10},
#         'person_descs': '박선호는 말을 듣고있다'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 111,
#         'min_y': 166,
#         'max_x': 1176,
#         'max_y': 998}}],
#      'image_descs': ['남자들은 대화중이다',
#       '남자들은 머리가 까맣다',
#       '남자들은 가까이 있다',
#       '뒤에 빨간 불빛이 비친다',
#       '남자들은 셔츠를 입고있다']},
#     {'image_id': 'KM_0000000473.jpg',
#      'frame_id': 473,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 1157,
#          'min_y': 387,
#          'max_x': 1567,
#          'max_y': 876},
#         'full_rect': {'min_x': 732,
#          'min_y': 173,
#          'max_x': 1739,
#          'max_y': 1030},
#         'behavior': 'none',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 0,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 10},
#         'person_descs': '박선호는 말을 듣고있다'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 86,
#         'min_y': 165,
#         'max_x': 1151,
#         'max_y': 997}}],
#      'image_descs': ['남자들은 대화중이다',
#       '남자들은 머리가 까맣다',
#       '남자들은 가까이 있다',
#       '뒤에 빨간 불빛이 비친다',
#       '남자들은 셔츠를 입고있다']},
#     {'image_id': 'KM_0000000474.jpg',
#      'frame_id': 474,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 1136,
#          'min_y': 395,
#          'max_x': 1538,
#          'max_y': 875},
#         'full_rect': {'min_x': 695,
#          'min_y': 168,
#          'max_x': 1723,
#          'max_y': 1041},
#         'behavior': 'none',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 0,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 10},
#         'person_descs': '박선호는 말을 듣고있다'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 62,
#         'min_y': 165,
#         'max_x': 1127,
#         'max_y': 996}}],
#      'image_descs': ['남자들은 대화중이다',
#       '남자들은 머리가 까맣다',
#       '남자들은 가까이 있다',
#       '뒤에 빨간 불빛이 비친다',
#       '남자들은 셔츠를 입고있다']},
#     {'image_id': 'KM_0000000475.jpg',
#      'frame_id': 475,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 1113,
#          'min_y': 398,
#          'max_x': 1515,
#          'max_y': 877},
#         'full_rect': {'min_x': 669,
#          'min_y': 172,
#          'max_x': 1696,
#          'max_y': 1046},
#         'behavior': 'none',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 0,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 10},
#         'person_descs': '박선호는 말을 듣고있다'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 37,
#         'min_y': 165,
#         'max_x': 1102,
#         'max_y': 997}}],
#      'image_descs': ['남자들은 대화중이다',
#       '남자들은 머리가 까맣다',
#       '남자들은 가까이 있다',
#       '뒤에 빨간 불빛이 비친다',
#       '남자들은 셔츠를 입고있다']},
#     {'image_id': 'KM_0000000476.jpg',
#      'frame_id': 476,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 1093,
#          'min_y': 400,
#          'max_x': 1495,
#          'max_y': 879},
#         'full_rect': {'min_x': 655,
#          'min_y': 182,
#          'max_x': 1662,
#          'max_y': 1039},
#         'behavior': 'none',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 0,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 10},
#         'person_descs': '박선호는 말을 듣고있다'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 13,
#         'min_y': 166,
#         'max_x': 1078,
#         'max_y': 998}}],
#      'image_descs': ['남자들은 대화중이다',
#       '남자들은 머리가 까맣다',
#       '남자들은 가까이 있다',
#       '뒤에 빨간 불빛이 비친다',
#       '남자들은 셔츠를 입고있다']},
#     {'image_id': 'KM_0000000477.jpg',
#      'frame_id': 477,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 1093,
#          'min_y': 401,
#          'max_x': 1495,
#          'max_y': 881},
#         'full_rect': {'min_x': 653,
#          'min_y': 182,
#          'max_x': 1660,
#          'max_y': 1038},
#         'behavior': 'none',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 0,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 10},
#         'person_descs': '박선호는 말을 듣고있다'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 10,
#         'min_y': 168,
#         'max_x': 1075,
#         'max_y': 999}}],
#      'image_descs': ['남자들은 대화중이다',
#       '남자들은 머리가 까맣다',
#       '남자들은 가까이 있다',
#       '뒤에 빨간 불빛이 비친다',
#       '남자들은 셔츠를 입고있다']},
#     {'image_id': 'KM_0000000478.jpg',
#      'frame_id': 478,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 1077,
#          'min_y': 404,
#          'max_x': 1479,
#          'max_y': 883},
#         'full_rect': {'min_x': 636,
#          'min_y': 182,
#          'max_x': 1643,
#          'max_y': 1038},
#         'behavior': 'none',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 0,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 10},
#         'person_descs': '박선호는 말을 듣고있다'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': -9,
#         'min_y': 165,
#         'max_x': 1055,
#         'max_y': 997}}],
#      'image_descs': ['남자들은 대화중이다',
#       '남자들은 머리가 까맣다',
#       '남자들은 가까이 있다',
#       '뒤에 빨간 불빛이 비친다',
#       '남자들은 셔츠를 입고있다']},
#     {'image_id': 'KM_0000000479.jpg',
#      'frame_id': 479,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 1067,
#          'min_y': 405,
#          'max_x': 1469,
#          'max_y': 885},
#         'full_rect': {'min_x': 622,
#          'min_y': 181,
#          'max_x': 1629,
#          'max_y': 1038},
#         'behavior': 'none',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 0,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 10},
#         'person_descs': '박선호는 말을 듣고있다'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': -24,
#         'min_y': 166,
#         'max_x': 1040,
#         'max_y': 998}}],
#      'image_descs': ['남자들은 대화중이다',
#       '남자들은 머리가 까맣다',
#       '남자들은 가까이 있다',
#       '뒤에 빨간 불빛이 비친다',
#       '남자들은 셔츠를 입고있다']},
#     {'image_id': 'KM_0000000480.jpg',
#      'frame_id': 480,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 1058,
#          'min_y': 406,
#          'max_x': 1460,
#          'max_y': 886},
#         'full_rect': {'min_x': 611,
#          'min_y': 180,
#          'max_x': 1618,
#          'max_y': 1036},
#         'behavior': 'none',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 0,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 10},
#         'person_descs': '박선호는 말을 듣고있다'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': -38,
#         'min_y': 167,
#         'max_x': 1027,
#         'max_y': 999}}],
#      'image_descs': ['남자들은 대화중이다',
#       '남자들은 머리가 까맣다',
#       '남자들은 가까이 있다',
#       '뒤에 빨간 불빛이 비친다',
#       '남자들은 셔츠를 입고있다']},
#     {'image_id': 'KM_0000000481.jpg',
#      'frame_id': 481,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 1052,
#          'min_y': 407,
#          'max_x': 1454,
#          'max_y': 886},
#         'full_rect': {'min_x': 599,
#          'min_y': 179,
#          'max_x': 1606,
#          'max_y': 1035},
#         'behavior': 'none',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 0,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 10},
#         'person_descs': '박선호는 말을 듣고있다'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': -50,
#         'min_y': 167,
#         'max_x': 1014,
#         'max_y': 999}}],
#      'image_descs': ['남자들은 대화중이다',
#       '남자들은 머리가 까맣다',
#       '남자들은 가까이 있다',
#       '뒤에 빨간 불빛이 비친다',
#       '남자들은 셔츠를 입고있다']},
#     {'image_id': 'KM_0000000482.jpg',
#      'frame_id': 482,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 1052,
#          'min_y': 407,
#          'max_x': 1454,
#          'max_y': 886},
#         'full_rect': {'min_x': 599,
#          'min_y': 179,
#          'max_x': 1606,
#          'max_y': 1035},
#         'behavior': 'none',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 0,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 10},
#         'person_descs': '박선호는 말을 듣고있다'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': -50,
#         'min_y': 167,
#         'max_x': 1014,
#         'max_y': 999}}],
#      'image_descs': ['남자들은 대화중이다',
#       '남자들은 머리가 까맣다',
#       '남자들은 가까이 있다',
#       '뒤에 빨간 불빛이 비친다',
#       '남자들은 셔츠를 입고있다']},
#     {'image_id': 'KM_0000000483.jpg',
#      'frame_id': 483,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 1008,
#          'min_y': 413,
#          'max_x': 1414,
#          'max_y': 895},
#         'full_rect': {'min_x': 609,
#          'min_y': 230,
#          'max_x': 1668,
#          'max_y': 1002},
#         'behavior': 'look at/back on',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 0,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 10},
#         'person_descs': '박선호가 옅은 미소를 띄고 있다.'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 597,
#         'min_y': 59,
#         'max_x': 842,
#         'max_y': 1021}}],
#      'image_descs': ['남자가 있다',
#       '남자는 줄무늬 옷을 입고있다',
#       '남자는 아래를 응시한다',
#       '남자는 머리가 까맣다',
#       '뒤에 빨간 불빛이 비친다']},
#     {'image_id': 'KM_0000000484.jpg',
#      'frame_id': 484,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 1008,
#          'min_y': 413,
#          'max_x': 1414,
#          'max_y': 895},
#         'full_rect': {'min_x': 609,
#          'min_y': 230,
#          'max_x': 1668,
#          'max_y': 1002},
#         'behavior': 'look at/back on',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 0,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 10},
#         'person_descs': '박선호가 옅은 미소를 띄고 있다.'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 597,
#         'min_y': 59,
#         'max_x': 842,
#         'max_y': 1021}}],
#      'image_descs': ['남자가 있다',
#       '남자는 줄무늬 옷을 입고있다',
#       '남자는 아래를 응시한다',
#       '남자는 머리가 까맣다',
#       '뒤에 빨간 불빛이 비친다']},
#     {'image_id': 'KM_0000000485.jpg',
#      'frame_id': 485,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 1003,
#          'min_y': 415,
#          'max_x': 1409,
#          'max_y': 897},
#         'full_rect': {'min_x': 602,
#          'min_y': 233,
#          'max_x': 1661,
#          'max_y': 1004},
#         'behavior': 'look at/back on',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 0,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 10},
#         'person_descs': '박선호가 옅은 미소를 띄고 있다.'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 585,
#         'min_y': 56,
#         'max_x': 835,
#         'max_y': 1038}}],
#      'image_descs': ['남자가 있다',
#       '남자는 줄무늬 옷을 입고있다',
#       '남자는 아래를 응시한다',
#       '남자는 머리가 까맣다',
#       '뒤에 빨간 불빛이 비친다']},
#     {'image_id': 'KM_0000000486.jpg',
#      'frame_id': 486,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 998,
#          'min_y': 415,
#          'max_x': 1404,
#          'max_y': 897},
#         'full_rect': {'min_x': 596,
#          'min_y': 232,
#          'max_x': 1656,
#          'max_y': 1003},
#         'behavior': 'look at/back on',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 0,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 10},
#         'person_descs': '박선호가 옅은 미소를 띄고 있다.'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 555,
#         'min_y': 25,
#         'max_x': 820,
#         'max_y': 1067}}],
#      'image_descs': ['남자가 있다',
#       '남자는 줄무늬 옷을 입고있다',
#       '남자는 아래를 응시한다',
#       '남자는 머리가 까맣다',
#       '뒤에 빨간 불빛이 비친다']},
#     {'image_id': 'KM_0000000487.jpg',
#      'frame_id': 487,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 996,
#          'min_y': 416,
#          'max_x': 1402,
#          'max_y': 898},
#         'full_rect': {'min_x': 592,
#          'min_y': 231,
#          'max_x': 1652,
#          'max_y': 1002},
#         'behavior': 'look at/back on',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 0,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 10},
#         'person_descs': '박선호가 옅은 미소를 띄고 있다.'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 513,
#         'min_y': 23,
#         'max_x': 778,
#         'max_y': 1065}}],
#      'image_descs': ['남자가 있다',
#       '남자는 줄무늬 옷을 입고있다',
#       '남자는 아래를 응시한다',
#       '남자는 머리가 까맣다',
#       '뒤에 빨간 불빛이 비친다']},
#     {'image_id': 'KM_0000000488.jpg',
#      'frame_id': 488,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 996,
#          'min_y': 416,
#          'max_x': 1402,
#          'max_y': 898},
#         'full_rect': {'min_x': 590,
#          'min_y': 233,
#          'max_x': 1649,
#          'max_y': 1004},
#         'behavior': 'look at/back on',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 0,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 10},
#         'person_descs': '박선호가 옅은 미소를 띄고 있다.'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 517,
#         'min_y': 57,
#         'max_x': 783,
#         'max_y': 1099}}],
#      'image_descs': ['남자가 있다',
#       '남자는 줄무늬 옷을 입고있다',
#       '남자는 아래를 응시한다',
#       '남자는 머리가 까맣다',
#       '뒤에 빨간 불빛이 비친다']},
#     {'image_id': 'KM_0000000489.jpg',
#      'frame_id': 489,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 997,
#          'min_y': 417,
#          'max_x': 1403,
#          'max_y': 899},
#         'full_rect': {'min_x': 589,
#          'min_y': 233,
#          'max_x': 1649,
#          'max_y': 1005},
#         'behavior': 'look at/back on',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 0,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 10},
#         'person_descs': '박선호가 옅은 미소를 띄고 있다.'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 513,
#         'min_y': 59,
#         'max_x': 778,
#         'max_y': 1101}}],
#      'image_descs': ['남자가 있다',
#       '남자는 줄무늬 옷을 입고있다',
#       '남자는 아래를 응시한다',
#       '남자는 머리가 까맣다',
#       '뒤에 빨간 불빛이 비친다']},
#     {'image_id': 'KM_0000000490.jpg',
#      'frame_id': 490,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 997,
#          'min_y': 416,
#          'max_x': 1403,
#          'max_y': 898},
#         'full_rect': {'min_x': 605, 'min_y': 249, 'max_x': 1623, 'max_y': 990},
#         'behavior': 'look at/back on',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 0,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 10},
#         'person_descs': '박선호가 옅은 미소를 띄고 있다.'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 487,
#         'min_y': 73,
#         'max_x': 747,
#         'max_y': 1094}}],
#      'image_descs': ['남자가 있다',
#       '남자는 줄무늬 옷을 입고있다',
#       '남자는 아래를 응시한다',
#       '남자는 머리가 까맣다',
#       '뒤에 빨간 불빛이 비친다']},
#     {'image_id': 'KM_0000000491.jpg',
#      'frame_id': 491,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 997,
#          'min_y': 417,
#          'max_x': 1403,
#          'max_y': 899},
#         'full_rect': {'min_x': 580,
#          'min_y': 230,
#          'max_x': 1639,
#          'max_y': 1001},
#         'behavior': 'look at/back on',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 0,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 10},
#         'person_descs': '박선호가 옅은 미소를 띄고 있다.'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 513,
#         'min_y': 67,
#         'max_x': 758,
#         'max_y': 1029}}],
#      'image_descs': ['남자가 있다',
#       '남자는 줄무늬 옷을 입고있다',
#       '남자는 아래를 응시한다',
#       '남자는 머리가 까맣다',
#       '뒤에 빨간 불빛이 비친다']},
#     {'image_id': 'KM_0000000492.jpg',
#      'frame_id': 492,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 1000,
#          'min_y': 417,
#          'max_x': 1406,
#          'max_y': 899},
#         'full_rect': {'min_x': 574, 'min_y': 218, 'max_x': 1634, 'max_y': 990},
#         'behavior': 'look at/back on',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 0,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 10},
#         'person_descs': '박선호가 옅은 미소를 띄고 있다.'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 445,
#         'min_y': 55,
#         'max_x': 685,
#         'max_y': 998}}],
#      'image_descs': ['남자가 있다',
#       '남자는 줄무늬 옷을 입고있다',
#       '남자는 아래를 응시한다',
#       '남자는 머리가 까맣다',
#       '뒤에 빨간 불빛이 비친다']},
#     {'image_id': 'KM_0000000493.jpg',
#      'frame_id': 493,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 1003,
#          'min_y': 417,
#          'max_x': 1409,
#          'max_y': 899},
#         'full_rect': {'min_x': 576, 'min_y': 220, 'max_x': 1635, 'max_y': 992},
#         'behavior': 'look at/back on',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 0,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 10},
#         'person_descs': '박선호가 옅은 미소를 띄고 있다.'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 353,
#         'min_y': 49,
#         'max_x': 588,
#         'max_y': 974}}],
#      'image_descs': ['남자가 있다',
#       '남자는 줄무늬 옷을 입고있다',
#       '남자는 아래를 응시한다',
#       '남자는 머리가 까맣다',
#       '뒤에 빨간 불빛이 비친다']},
#     {'image_id': 'KM_0000000494.jpg',
#      'frame_id': 494,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 1006,
#          'min_y': 417,
#          'max_x': 1412,
#          'max_y': 899},
#         'full_rect': {'min_x': 578, 'min_y': 220, 'max_x': 1637, 'max_y': 991},
#         'behavior': 'look at/back on',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 0,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 10},
#         'person_descs': '박선호가 옅은 미소를 띄고 있다.'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 336,
#         'min_y': 44,
#         'max_x': 572,
#         'max_y': 969}}],
#      'image_descs': ['남자가 있다',
#       '남자는 줄무늬 옷을 입고있다',
#       '남자는 아래를 응시한다',
#       '남자는 머리가 까맣다',
#       '뒤에 빨간 불빛이 비친다']},
#     {'image_id': 'KM_0000000495.jpg',
#      'frame_id': 495,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 1010,
#          'min_y': 415,
#          'max_x': 1416,
#          'max_y': 897},
#         'full_rect': {'min_x': 578, 'min_y': 221, 'max_x': 1637, 'max_y': 992},
#         'behavior': 'look at/back on',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 0,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 10},
#         'person_descs': '박선호가 옅은 미소를 띄고 있다.'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 249,
#         'min_y': 44,
#         'max_x': 480,
#         'max_y': 951}}],
#      'image_descs': ['남자가 있다',
#       '남자는 줄무늬 옷을 입고있다',
#       '남자는 아래를 응시한다',
#       '남자는 머리가 까맣다',
#       '뒤에 빨간 불빛이 비친다']},
#     {'image_id': 'KM_0000000496.jpg',
#      'frame_id': 496,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 1016,
#          'min_y': 414,
#          'max_x': 1422,
#          'max_y': 896},
#         'full_rect': {'min_x': 579, 'min_y': 216, 'max_x': 1638, 'max_y': 987},
#         'behavior': 'look at/back on',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 0,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 10},
#         'person_descs': '박선호가 옅은 미소를 띄고 있다.'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 258,
#         'min_y': 85,
#         'max_x': 485,
#         'max_y': 974}}],
#      'image_descs': ['남자가 있다',
#       '남자는 줄무늬 옷을 입고있다',
#       '남자는 아래를 응시한다',
#       '남자는 머리가 까맣다',
#       '뒤에 빨간 불빛이 비친다']},
#     {'image_id': 'KM_0000000497.jpg',
#      'frame_id': 497,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 1024,
#          'min_y': 411,
#          'max_x': 1430,
#          'max_y': 893},
#         'full_rect': {'min_x': 581, 'min_y': 219, 'max_x': 1640, 'max_y': 990},
#         'behavior': 'look at/back on',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 0,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 10},
#         'person_descs': '박선호가 옅은 미소를 띄고 있다.'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 301,
#         'min_y': 119,
#         'max_x': 528,
#         'max_y': 1008}}],
#      'image_descs': ['남자가 있다',
#       '남자는 줄무늬 옷을 입고있다',
#       '남자는 아래를 응시한다',
#       '남자는 머리가 까맣다',
#       '뒤에 빨간 불빛이 비친다']},
#     {'image_id': 'KM_0000000498.jpg',
#      'frame_id': 498,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 1029,
#          'min_y': 406,
#          'max_x': 1435,
#          'max_y': 888},
#         'full_rect': {'min_x': 581, 'min_y': 217, 'max_x': 1640, 'max_y': 988},
#         'behavior': 'look at/back on',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 0,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 10},
#         'person_descs': '박선호가 옅은 미소를 띄고 있다.'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 200,
#         'min_y': 139,
#         'max_x': 422,
#         'max_y': 1011}}],
#      'image_descs': ['남자가 있다',
#       '남자는 줄무늬 옷을 입고있다',
#       '남자는 아래를 응시한다',
#       '남자는 머리가 까맣다',
#       '뒤에 빨간 불빛이 비친다']},
#     {'image_id': 'KM_0000000499.jpg',
#      'frame_id': 499,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 1030,
#          'min_y': 405,
#          'max_x': 1436,
#          'max_y': 887},
#         'full_rect': {'min_x': 585, 'min_y': 209, 'max_x': 1645, 'max_y': 980},
#         'behavior': 'look at/back on',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 0,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 10},
#         'person_descs': '박선호가 옅은 미소를 띄고 있다.'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 200,
#         'min_y': 130,
#         'max_x': 427,
#         'max_y': 1019}}],
#      'image_descs': ['남자가 있다',
#       '남자는 줄무늬 옷을 입고있다',
#       '남자는 아래를 응시한다',
#       '남자는 머리가 까맣다',
#       '뒤에 빨간 불빛이 비친다']},
#     {'image_id': 'KM_0000000500.jpg',
#      'frame_id': 500,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 1035,
#          'min_y': 399,
#          'max_x': 1441,
#          'max_y': 881},
#         'full_rect': {'min_x': 585, 'min_y': 219, 'max_x': 1645, 'max_y': 991},
#         'behavior': 'look at/back on',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 0,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 10},
#         'person_descs': '박선호가 옅은 미소를 띄고 있다.'},
#        'related_objects': []}],
# ...
#          'min_y': 248,
#          'max_x': 544,
#          'max_y': 515},
#         'full_rect': {'min_x': 20, 'min_y': 106, 'max_x': 804, 'max_y': 1072},
#         'behavior': 'sit down',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 10,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 0},
#         'person_descs': '박두식이 웃고있다'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 1263,
#         'min_y': 283,
#         'max_x': 1871,
#         'max_y': 1071}},
#       {'object_id': 'cup',
#        'object_rect': {'min_x': 689,
#         'min_y': 957,
#         'max_x': 793,
#         'max_y': 1064}}],
#      'image_descs': ['남자 두명과 여자한명이 있다',
#       '남자들은 웃고있다',
#       '과일이 놓여있다',
#       '여자는 머리를 묶었다',
#       '술을 마시고있다']},
#     {'image_id': 'KM_0000000032.jpg',
#      'frame_id': 32,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 1021,
#          'min_y': 314,
#          'max_x': 1228,
#          'max_y': 550},
#         'full_rect': {'min_x': 778,
#          'min_y': 182,
#          'max_x': 1430,
#          'max_y': 1057},
#         'behavior': 'talking',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 10,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 0},
#         'person_descs': '박선호가 말하고있다'},
#        'related_objects': []},
#       {'person_id': '박두식',
#        'person_info': {'face_rect': {'min_x': 325,
#          'min_y': 248,
#          'max_x': 544,
#          'max_y': 515},
#         'full_rect': {'min_x': 19, 'min_y': 108, 'max_x': 803, 'max_y': 1074},
#         'behavior': 'sit down',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 10,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 0},
#         'person_descs': '박두식이 웃고있다'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 1261,
#         'min_y': 284,
#         'max_x': 1870,
#         'max_y': 1071}},
#       {'object_id': 'cup',
#        'object_rect': {'min_x': 689,
#         'min_y': 958,
#         'max_x': 793,
#         'max_y': 1065}}],
#      'image_descs': ['남자 두명과 여자한명이 있다',
#       '남자들은 웃고있다',
#       '과일이 놓여있다',
#       '여자는 머리를 묶었다',
#       '술을 마시고있다']},
#     {'image_id': 'KM_0000000033.jpg',
#      'frame_id': 33,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 1021,
#          'min_y': 314,
#          'max_x': 1228,
#          'max_y': 550},
#         'full_rect': {'min_x': 778,
#          'min_y': 182,
#          'max_x': 1430,
#          'max_y': 1057},
#         'behavior': 'talking',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 10,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 0},
#         'person_descs': '박선호가 말하고있다'},
#        'related_objects': []},
#       {'person_id': '박두식',
#        'person_info': {'face_rect': {'min_x': 325,
#          'min_y': 248,
#          'max_x': 544,
#          'max_y': 515},
#         'full_rect': {'min_x': 19, 'min_y': 108, 'max_x': 803, 'max_y': 1074},
#         'behavior': 'sit down',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 10,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 0},
#         'person_descs': '박두식이 웃고있다'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 1261,
#         'min_y': 284,
#         'max_x': 1870,
#         'max_y': 1071}},
#       {'object_id': 'cup',
#        'object_rect': {'min_x': 689,
#         'min_y': 958,
#         'max_x': 793,
#         'max_y': 1065}}],
#      'image_descs': ['남자 두명과 여자한명이 있다',
#       '남자들은 웃고있다',
#       '과일이 놓여있다',
#       '여자는 머리를 묶었다',
#       '술을 마시고있다']},
#     {'image_id': 'KM_0000000034.jpg',
#      'frame_id': 34,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 1035,
#          'min_y': 322,
#          'max_x': 1230,
#          'max_y': 557},
#         'full_rect': {'min_x': 765,
#          'min_y': 207,
#          'max_x': 1398,
#          'max_y': 1062},
#         'behavior': 'eat',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 10,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 0},
#         'person_descs': '박선호가 음식을 먹으려한다'},
#        'related_objects': []},
#       {'person_id': '박두식',
#        'person_info': {'face_rect': {'min_x': 323,
#          'min_y': 247,
#          'max_x': 546,
#          'max_y': 518},
#         'full_rect': {'min_x': 0, 'min_y': 77, 'max_x': 835, 'max_y': 1111},
#         'behavior': 'sit down',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 10,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 0},
#         'person_descs': '박두식이 앉아있다'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 1270,
#         'min_y': 312,
#         'max_x': 1912,
#         'max_y': 1070}},
#       {'object_id': 'cup',
#        'object_rect': {'min_x': 709,
#         'min_y': 946,
#         'max_x': 790,
#         'max_y': 1069}},
#       {'object_id': 'chair',
#        'object_rect': {'min_x': 0, 'min_y': 698, 'max_x': 88, 'max_y': 1068}},
#       {'object_id': 'chair',
#        'object_rect': {'min_x': 674,
#         'min_y': 627,
#         'max_x': 832,
#         'max_y': 999}}],
#      'image_descs': ['남자 두명과 여자 한명이 있다',
#       '남자들은 여자를 보고있다',
#       '여자는 머리를 묶었다',
#       '여자는 머리가 까맣다',
#       '과일이 놓여있다']},
#     {'image_id': 'KM_0000000035.jpg',
#      'frame_id': 35,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 1035,
#          'min_y': 322,
#          'max_x': 1230,
#          'max_y': 557},
#         'full_rect': {'min_x': 765,
#          'min_y': 207,
#          'max_x': 1398,
#          'max_y': 1062},
#         'behavior': 'eat',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 10,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 0},
#         'person_descs': '박선호가 음식을 먹으려한다'},
#        'related_objects': []},
#       {'person_id': '박두식',
#        'person_info': {'face_rect': {'min_x': 323,
#          'min_y': 247,
#          'max_x': 546,
#          'max_y': 518},
#         'full_rect': {'min_x': 0, 'min_y': 77, 'max_x': 835, 'max_y': 1111},
#         'behavior': 'sit down',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 10,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 0},
#         'person_descs': '박두식이 앉아있다'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 1270,
#         'min_y': 312,
#         'max_x': 1912,
#         'max_y': 1070}},
#       {'object_id': 'cup',
#        'object_rect': {'min_x': 709,
#         'min_y': 946,
#         'max_x': 790,
#         'max_y': 1069}},
#       {'object_id': 'chair',
#        'object_rect': {'min_x': 0, 'min_y': 698, 'max_x': 88, 'max_y': 1068}},
#       {'object_id': 'chair',
#        'object_rect': {'min_x': 674,
#         'min_y': 627,
#         'max_x': 832,
#         'max_y': 999}}],
#      'image_descs': ['남자 두명과 여자 한명이 있다',
#       '남자들은 여자를 보고있다',
#       '여자는 머리를 묶었다',
#       '여자는 머리가 까맣다',
#       '과일이 놓여있다']},
#     {'image_id': 'KM_0000000036.jpg',
#      'frame_id': 36,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 1039,
#          'min_y': 322,
#          'max_x': 1234,
#          'max_y': 557},
#         'full_rect': {'min_x': 767,
#          'min_y': 207,
#          'max_x': 1400,
#          'max_y': 1062},
#         'behavior': 'eat',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 10,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 0},
#         'person_descs': '박선호가 음식을 먹으려한다'},
#        'related_objects': []},
#       {'person_id': '박두식',
#        'person_info': {'face_rect': {'min_x': 326,
#          'min_y': 249,
#          'max_x': 549,
#          'max_y': 520},
#         'full_rect': {'min_x': 8, 'min_y': 87, 'max_x': 828, 'max_y': 1100},
#         'behavior': 'sit down',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 10,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 0},
#         'person_descs': '박두식이 앉아있다'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 1268,
#         'min_y': 317,
#         'max_x': 1910,
#         'max_y': 1075}},
#       {'object_id': 'cup',
#        'object_rect': {'min_x': 707,
#         'min_y': 946,
#         'max_x': 788,
#         'max_y': 1069}},
#       {'object_id': 'chair',
#        'object_rect': {'min_x': 3, 'min_y': 698, 'max_x': 91, 'max_y': 1068}},
#       {'object_id': 'chair',
#        'object_rect': {'min_x': 674,
#         'min_y': 626,
#         'max_x': 832,
#         'max_y': 999}}],
#      'image_descs': ['남자 두명과 여자 한명이 있다',
#       '남자들은 여자를 보고있다',
#       '여자는 머리를 묶었다',
#       '여자는 머리가 까맣다',
#       '과일이 놓여있다']},
#     {'image_id': 'KM_0000000037.jpg',
#      'frame_id': 37,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 1043,
#          'min_y': 323,
#          'max_x': 1238,
#          'max_y': 558},
#         'full_rect': {'min_x': 765,
#          'min_y': 206,
#          'max_x': 1398,
#          'max_y': 1061},
#         'behavior': 'eat',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 10,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 0},
#         'person_descs': '박선호가 음식을 먹으려한다'},
#        'related_objects': []},
#       {'person_id': '박두식',
#        'person_info': {'face_rect': {'min_x': 327,
#          'min_y': 249,
#          'max_x': 554,
#          'max_y': 525},
#         'full_rect': {'min_x': 17, 'min_y': 95, 'max_x': 820, 'max_y': 1089},
#         'behavior': 'sit down',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 10,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 0},
#         'person_descs': '박두식이 앉아있다'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 1271,
#         'min_y': 328,
#         'max_x': 1900,
#         'max_y': 1072}},
#       {'object_id': 'cup',
#        'object_rect': {'min_x': 708,
#         'min_y': 947,
#         'max_x': 788,
#         'max_y': 1067}},
#       {'object_id': 'chair',
#        'object_rect': {'min_x': 4, 'min_y': 694, 'max_x': 93, 'max_y': 1071}},
#       {'object_id': 'chair',
#        'object_rect': {'min_x': 674,
#         'min_y': 624,
#         'max_x': 832,
#         'max_y': 997}}],
#      'image_descs': ['남자 두명과 여자 한명이 있다',
#       '남자들은 여자를 보고있다',
#       '여자는 머리를 묶었다',
#       '여자는 머리가 까맣다',
#       '과일이 놓여있다']},
#     {'image_id': 'KM_0000000038.jpg',
#      'frame_id': 38,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 1045,
#          'min_y': 323,
#          'max_x': 1240,
#          'max_y': 558},
#         'full_rect': {'min_x': 765,
#          'min_y': 206,
#          'max_x': 1398,
#          'max_y': 1061},
#         'behavior': 'eat',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 10,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 0},
#         'person_descs': '박선호가 음식을 먹으려한다'},
#        'related_objects': []},
#       {'person_id': '박두식',
#        'person_info': {'face_rect': {'min_x': 331,
#          'min_y': 253,
#          'max_x': 554,
#          'max_y': 524},
#         'full_rect': {'min_x': 24, 'min_y': 104, 'max_x': 812, 'max_y': 1078},
#         'behavior': 'sit down',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 10,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 0},
#         'person_descs': '박두식이 앉아있다'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 1270,
#         'min_y': 329,
#         'max_x': 1899,
#         'max_y': 1073}},
#       {'object_id': 'cup',
#        'object_rect': {'min_x': 708,
#         'min_y': 947,
#         'max_x': 788,
#         'max_y': 1067}},
#       {'object_id': 'chair',
#        'object_rect': {'min_x': 5, 'min_y': 697, 'max_x': 93, 'max_y': 1067}},
#       {'object_id': 'chair',
#        'object_rect': {'min_x': 677,
#         'min_y': 626,
#         'max_x': 832,
#         'max_y': 992}}],
#      'image_descs': ['남자 두명과 여자 한명이 있다',
#       '남자들은 여자를 보고있다',
#       '여자는 머리를 묶었다',
#       '여자는 머리가 까맣다',
#       '과일이 놓여있다']},
#     {'image_id': 'KM_0000000039.jpg',
#      'frame_id': 39,
#      'place': 'restaurant',
#      'persons': [{'person_id': '박선호',
#        'person_info': {'face_rect': {'min_x': 1045,
#          'min_y': 323,
#          'max_x': 1240,
#          'max_y': 558},
#         'full_rect': {'min_x': 765,
#          'min_y': 206,
#          'max_x': 1398,
#          'max_y': 1061},
#         'behavior': 'eat',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 10,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 0},
#         'person_descs': '박선호가 음식을 먹으려한다'},
#        'related_objects': []},
#       {'person_id': '박두식',
#        'person_info': {'face_rect': {'min_x': 331,
#          'min_y': 253,
#          'max_x': 554,
#          'max_y': 524},
#         'full_rect': {'min_x': 30, 'min_y': 115, 'max_x': 802, 'max_y': 1070},
#         'behavior': 'sit down',
#         'gender': 'male',
#         'generation': "20's",
#         'emotion': {'happiness': 10,
#          'sadness': 0,
#          'anger': 0,
#          'surprise': 0,
#          'afraid': 0,
#          'contempt': 0,
#          'disgust': 0,
#          'neutral': 0},
#         'person_descs': '박두식이 앉아있다'},
#        'related_objects': []}],
#      'objects': [{'object_id': 'person',
#        'object_rect': {'min_x': 1270,
#         'min_y': 329,
#         'max_x': 1899,
#         'max_y': 1073}},
#       {'object_id': 'cup',
#        'object_rect': {'min_x': 707,
#         'min_y': 947,
#         'max_x': 787,
#         'max_y': 1067}},
#       {'object_id': 'chair',
#        'object_rect': {'min_x': 4, 'min_y': 696, 'max_x': 92, 'max_y': 1066}},
#       {'object_id': 'chair',
#        'object_rect': {'min_x': 679,
#         'min_y': 629,
#         'max_x': 831,
#         'max_y': 987}}],
#      'image_descs': ['남자 두명과 여자 한명이 있다',
#       '남자들은 여자를 보고있다',
#       '여자는 머리를 묶었다',
#       '여자는 머리가 까맣다',
#       '과일이 놓여있다']}]}]}

# %%
json_data['shot_infos'][0]['image_folder']
# Out:
# 'KETI_SHOT_0000145756'

# %%
json_data['shot_infos'][0]['visual_infos'][0]['image_id']
# Out:
# 'KM_0000000448.jpg'

# %%
len(json_data['shot_infos'])
# Out:
# 10

# %%
for i in range(10):
    print(json_data['shot_infos'][i]['visual_infos'][0]['image_descs'])
# Out:
# ['남자들이 있다', '남자들은 서로 쳐다보고있다', '남자는 검정머리이다', '남자는 흰 셔츠를 입고있다', '남자는 옆을 보고있다']
# ['과일이 있다', '여자 두명이 나란히 앉아있다', '술마시고있다', '여자들 맞은편에 사람이 있다', '모두 앉아있다']
# ['남자가 있다', '남자가 입을 벌리고있다', '남자는 검정 머리이다', '남자는 흰 셔츠를 입었다', '남자 둘이 나란히 앉아있다']
# ['맞은편에 사람이 있다', '여자 두명이 있다', '사람들이 앉아있다', '술을 마시고있다', '과일이 있다']
# ['남자가 두명 있다', '남자들은 서로 쳐다본다', '남자들 맞은편에 여자가 있다', '과일이 놓여있다', '술이 있다']
# ['남자는 옆을 본다', '남자는 셔츠를 입고있다', '뒤에 불빛이 비친다', '남자는 흰옷을 입고있다', '남자는 검은 머리이다']
# ['여자 두명이 있다', '맞은편에 남자가 있다', '과일이 식탁에 놓여있다', '술을 마시고있다', '모두 앉아있다']
# ['남자가 두명있다', '맞은편에 여자가 있다', '여자는 머리를 묶었다', '사람들은 앉아있다', '과일이 놓여있다']
# ['남자가 있다', '여자가 두명 있다', '과일이 놓여있다', '술을 마시고있다', '사람들은 앉아있다']
# ['남자 두명과 여자 한명이 있다', '모두 앉아있다', '과일이 놓여있다', '남자들은 웃고있다', '여자는 머리를 묶었다']

# %%
  with open(f'{path}/{folder_name}/{file_name}', 'r') as f:
            json_data = json.load(f)
            tmp = pd.DataFrame(json_data)
            tmp = tmp[['description', 'annotations']][:15]
            tmp['description'][8:15] = tmp['annotations'][8:15] # 데이터프레임 내용 병합
            del(tmp['annotations']) # 필요없는 열 삭제
            tmp = tmp.T # 전치
            df = df.append(tmp) # df에 추가
            df['name'] = folder_name[4:] # 구분을 위한 name 열 생성
            df_raw = df_raw.append(df) # 최종 데이터 프레임에 추가

df_raw
