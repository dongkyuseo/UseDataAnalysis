# %%
# key 암호화
filename= 'data/odkey.txt'

with open(filename) as f:
  api_key = f.read()
len(api_key)
# Out:
# 51

# %%
import os
import sys
import requests
client_id = api_key.split('\n')[0]
client_secret = api_key.split('\n')[1]
url = "https://naveropenapi.apigw.ntruss.com/vision-obj/v1/detect"
img = 'data/img/images.jpg'
files = {'image': open(img, 'rb')}
out_file = 'data/images.json'
headers = {'X-NCP-APIGW-API-KEY-ID': client_id, 'X-NCP-APIGW-API-KEY': client_secret }
response = requests.post(url,  files=files, headers=headers)
rescode = response.status_code
if(rescode==200):
    print (response.text)
else:
    print("Error Code:" + rescode)
# Out:
# {"predictions": [{"num_detections": 7, "detection_classes": [1.0, 1.0, 9.0, 1.0, 8.0, 9.0, 3.0], "detection_names": ["person", "person", "boat", "person", "truck", "boat", "car"], "detection_scores": [0.992906, 0.956839, 0.792064, 0.577957, 0.485976, 0.358709, 0.302771], "detection_boxes": [[0.649504, 0.343201, 0.969924, 0.527496], [0.616663, 0.48785, 0.964729, 0.656005], [0.605847, 0.032411, 0.700165, 0.13429], [0.0648614, 0.601206, 0.735947, 0.963709], [0.610091, 0.0341494, 0.69625, 0.136908], [0.630163, 0.612498, 0.68129, 0.691448], [0.630629, 0.611155, 0.683985, 0.690537]]}]}

# %%
from PIL import Image
Image.open(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183 at 0x19404049460>

# %%
res = json.loads(response.text.encode('utf8'))
print(res)
# Out:
# {'predictions': [{'num_detections': 7, 'detection_classes': [1.0, 1.0, 9.0, 1.0, 8.0, 9.0, 3.0], 'detection_names': ['person', 'person', 'boat', 'person', 'truck', 'boat', 'car'], 'detection_scores': [0.992906, 0.956839, 0.792064, 0.577957, 0.485976, 0.358709, 0.302771], 'detection_boxes': [[0.649504, 0.343201, 0.969924, 0.527496], [0.616663, 0.48785, 0.964729, 0.656005], [0.605847, 0.032411, 0.700165, 0.13429], [0.0648614, 0.601206, 0.735947, 0.963709], [0.610091, 0.0341494, 0.69625, 0.136908], [0.630163, 0.612498, 0.68129, 0.691448], [0.630629, 0.611155, 0.683985, 0.690537]]}]}

# %%
import json
import requests
import os
import sys
import numpy as np
import pandas as pd

out_file = 'data/images.json'
with open(out_file, 'w', encoding='utf-8') as outfile:
    json.dump(res, outfile, indent=4, ensure_ascii=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-e9bab7b2ebd1> in <module>
#       8 out_file = 'data/images.json'
#       9 with open(out_file, 'w', encoding='utf-8') as outfile:
# ---> 10     json.dump(outfile, indent=4, ensure_ascii=False)
#
# TypeError: dump() missing 1 required positional argument: 'fp'
