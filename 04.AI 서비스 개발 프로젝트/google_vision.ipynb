# %%
# !gcloud auth application-default print-access-token
# Out:
# ya29.c.b0AXv0zTODgkhLD6voBCbp8LU7pp_0EB_7Bqay5aR2qk2G5-uuxoWwb4ek4QHMqzOmTKCTW606MQWVQmcZBKiKnEma1p1RJtOvScsDjNbx7d81ZPfSvhQEBDelcKJLx7dJlprJAh_OrGFlo4qc_Ev1Zx5AY10Z3ZhXmEjGSMxd-8V6jM5rvb4BDKnAnN6PLg7_3K1iWSOkBB3ivl6O3O3CpGPGfI-jfQ

# %%
# !wget https://raw.githubusercontent.com/googleapis/python-vision/master/samples/snippets/quickstart/resources/wakeupcat.jpg
# Out:
# 'wget'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.

# %%
image_path = 'data/testimg/images.jpg'

# %%
import io
import os

# Imports the Google Cloud client library
from google.cloud import vision
# Instantiates a client
client = vision.ImageAnnotatorClient()
# The name of the image file to annotate
file_name = os.path.abspath('data/testimg/images.jpg')

# Loads the image into memory
with io.open(file_name, 'rb') as image_file:
    content = image_file.read()

image = vision.Image(content=content)

# Performs label detection on the image file
response = client.label_detection(image=image)
labels = response.label_annotations

print('Labels:')
for label in labels:
    print(label.description)
# Out:
# Labels:
# Water
# Cloud
# Sky
# People on beach
# Beach
# Nature
# Azure
# Travel
# Tree
# Coastal and oceanic landforms

# %%
from PIL import Image
Image.open(image_path)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183 at 0x1DB0DB6FC70>

# %%
path = 'data/testimg/'
test = os.listdir(path)

# %%
import io
import os
from PIL import Image
from matplotlib.pyplot import imshow
import numpy as np

# %matplotlib inline

for i in test:
    image_path = i

    # Imports the Google Cloud client library
    from google.cloud import vision
    # Instantiates a client
    client = vision.ImageAnnotatorClient()
    # The name of the image file to annotate
    file_name = os.path.abspath(path+i)

    # Loads the image into memory
    with io.open(file_name, 'rb') as image_file:
        content = image_file.read()

    image = vision.Image(content=content)

    # Performs label detection on the image file
    response = client.label_detection(image=image)
    labels = response.label_annotations
    l_list = []
    print('Labels:')
    for label in labels:
        l_list.append(label.description)
    print(l_list)
    pil_im = Image.open(path+i)
    imshow(np.asarray(pil_im))
# Out:
# Labels:
# ['Sky', 'Plant', 'Skyscraper', 'Building', 'Natural environment', 'Natural landscape', 'Tree', 'Vegetation', 'Tower block', 'Land lot']
# AxesImage(54,36;334.8x217.44)
# Labels:
# ['Water', 'Cloud', 'Sky', 'People on beach', 'Beach', 'Nature', 'Azure', 'Travel', 'Tree', 'Coastal and oceanic landforms']
# AxesImage(54,36;334.8x217.44)
# Labels:
# ['Water', 'Sky', 'Cloud', 'Liquid', 'Fluid', 'Coastal and oceanic landforms', 'Beach', 'Landscape', 'Horizon', 'Natural landscape']
# AxesImage(54,36;334.8x217.44)
# Labels:
# ['Water', 'Cloud', 'Sky', 'Blue', 'Coastal and oceanic landforms', 'Horizon', 'Waterway', 'Wind wave', 'Landscape', 'Calm']
# AxesImage(54,36;334.8x217.44)
# Labels:
# ['Zebra', 'Plant', 'Fence', 'Tree', 'Fawn', 'Grass', 'Leisure', 'Terrestrial animal', 'Landscape', 'Recreation']
# AxesImage(54,36;334.8x217.44)
