# %%
## 캐글 대용량 파일 받는 방법
# 캐글 데이터 셋 
# !pip install kaggle --upgrade
# !pip install kaggle
# Out:
# Collecting kaggle
#   Downloading kaggle-1.5.12.tar.gz (58 kB)
# Requirement already satisfied: six>=1.10 in c:\programdata\anaconda3\lib\site-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from kaggle) (2021.5.30)
# Requirement already satisfied: python-dateutil in c:\programdata\anaconda3\lib\site-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from kaggle) (2.25.1)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from kaggle) (4.62.1)
# Collecting python-slugify
#   Downloading python_slugify-5.0.2-py2.py3-none-any.whl (6.7 kB)
# Requirement already satisfied: urllib3 in c:\programdata\anaconda3\lib\site-packages (from kaggle) (1.26.6)
# Collecting text-unidecode>=1.3
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
# Requirement already satisfied: idna<3,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->kaggle) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests->kaggle) (4.0.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm->kaggle) (0.4.4)
# Building wheels for collected packages: kaggle
#   Building wheel for kaggle (setup.py): started
#   Building wheel for kaggle (setup.py): finished with status 'done'
#   Created wheel for kaggle: filename=kaggle-1.5.12-py3-none-any.whl size=73052 sha256=ed5d51d50827f24da6f9ef28333cc94a2863ca0ffece36b1fb3ff77d91999dd5
#   Stored in directory: c:\users\dq\appdata\local\pip\cache\wheels\29\da\11\144cc25aebdaeb4931b231e25fd34b394e6a5725cbb2f50106
# Successfully built kaggle
# Installing collected packages: text-unidecode, python-slugify, kaggle
# Successfully installed kaggle-1.5.12 python-slugify-5.0.2 text-unidecode-1.3
# Requirement already satisfied: kaggle in c:\programdata\anaconda3\lib\site-packages (1.5.12)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from kaggle) (4.62.1)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from kaggle) (2021.5.30)
# Requirement already satisfied: python-slugify in c:\programdata\anaconda3\lib\site-packages (from kaggle) (5.0.2)
# Requirement already satisfied: urllib3 in c:\programdata\anaconda3\lib\site-packages (from kaggle) (1.26.6)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from kaggle) (2.25.1)
# Requirement already satisfied: python-dateutil in c:\programdata\anaconda3\lib\site-packages (from kaggle) (2.8.2)
# Requirement already satisfied: six>=1.10 in c:\programdata\anaconda3\lib\site-packages (from kaggle) (1.16.0)
# Requirement already satisfied: text-unidecode>=1.3 in c:\programdata\anaconda3\lib\site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests->kaggle) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->kaggle) (2.10)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm->kaggle) (0.4.4)

# %%
import json
with open('./data/kaggle.json') as fp:
  config_str = fp.read()
config = json.loads(config_str)

# %%
username = config['username'], 
password = config['password'],

# %%
import os
# os.environ을 이용하여 Kaggle API Username, Key 세팅하기
# kaggle.json 파일 열어서 user명과 key값 확인
os.environ['KAGGLE_USERNAME'] = 'dongkyuseo'
os.environ['KAGGLE_KEY'] = '32c3fe9aef741e20915ccb62eb1b85b4'

# %%
# !kaggle datasets download uciml/red-wine-quality-cortez-et-al-2009
# Out:
# Downloading red-wine-quality-cortez-et-al-2009.zip to d:\Workspace\03.UseDataAnalysis\02.실전 빅데이터 분석 프로젝트
#   0%|          | 0.00/25.6k [00:00<?, ?B/s]
# 100%|██████████| 25.6k/25.6k [00:00<00:00, 7.54MB/s]

# %%
import os
 
def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSError:
        print ('Error: Creating directory. ' +  directory)
 
createFolder('./zip')

# %%
import zipfile
fantasy_zip = zipfile.ZipFile('red-wine-quality-cortez-et-al-2009.zip')
fileName=fantasy_zip.namelist()[0]
fantasy_zip.extract(fileName,'./zip')

#fantasy_zip.close()
# Out:
# 'zip\\winequality-red.csv'

# %%
import pandas as pd

# 아래처럼 하면 많은 양의 csv 자동화가능 for문
from glob import glob
df = pd.read_csv(glob('./zip/*.csv')[0])
df


# 단건 자료를 가져올땐 아래처럼 할 수도 있음
# pd.read_csv('./zip/winequality-red.csv')
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]
